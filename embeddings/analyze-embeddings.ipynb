# %%
import pandas as pd
import numpy as np
from time import process_time
import ast
import re
import regex
import csv
from string import punctuation
from nltk.stem import WordNetLemmatizer
import unicodedata
from collections import OrderedDict 
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from nltk.stem import WordNetLemmatizer
import matplotlib.pyplot as plt

# %matplotlib notebook

# %% [markdown]
# # Read and Preprocess data

# %%
class Preprocess:
        
    # --------------------------------------- Constructor ------------------------------------------------

    def __init__(self):
        file = open("../marathi-stopwords.txt")
        self.stopword_list = []
        for row in file:
            self.stopword_list.append(re.sub('\n', '', row))


    # --------------------------------------- Clean Data -------------------------------------------------    
    
    def read_data(self, path):
        return pd.read_csv(path)

    
   # --------------------------------------- Expand Concatenations --------------------------------------- 
        
    def expand_concatenations(self, word):            
        if not re.match('[a-zA-Z]+', word) or re.match('\d+',word):
            for i in range(len(word)):
                if not('DEVANAGARI ' in unicodedata.name(word[i])):
                    word = word[:i] if( len(word[i:]) < 2 and not word[i:].isnumeric()) else word[:i] + " " + word[i:]
                    break
        else:
            for i in range(len(word)):
                if ('DEVANAGARI ' in unicodedata.name(word[i])):
                    word = word[i:] if( len(word[:i]) < 2 and not word[:i].isnumeric() ) else word[:i] + " " + word[i:]
                    break
        return(word)


    # --------------------------------------- Preprocess --------------------------------------- 

    def preprocess_data(self, text: str) -> str:
        try:
            if not(isinstance(text, str)): text = str(text)

            #Removing unprintable characters
            text = ''.join(x for x in text if x.isprintable())

            # Cleaning the urls
            text = re.sub(r'https?://\S+|www\.\S+', '', text)

            # Cleaning the html elements
            text = re.sub(r'<.*?>', '', text)

            # Removing the punctuations
            text = re.sub('[!#?,.:";-@#$%^&*_~<>()-]', '', text)


            # Removing stop words
            text = ' '.join([word for word in text.split() if word not in self.stopword_list])

            # Expanding noisy concatenations (Eg: algorithmआणि  -> algorithm आणि ) 
            text = ' '.join([self.expand_concatenations(word) for word in text.split()])

            preprocessed_text = ""

            for word in text.split(): 
                if (re.match('\d+', word)):
                    if(word.isnumeric()):
                        preprocessed_text = preprocessed_text + '#N' + " "
                else:
                    if(re.match('[a-zA-Z]+', word)):
                        if not len(word) < 2:
                            preprocessed_text = preprocessed_text + word.lower() + " "
                    else:
                        preprocessed_text = preprocessed_text + word + " "

            return preprocessed_text.strip()

        except ValueError as ve:
            print('Error processing:\t',text)
            return ''

# %%
obj = Preprocess()

# %%
training_path = "../dataset/original-dataset/marathi-training-data.csv"
training_data = obj.read_data(training_path)
training_data
# Out:
#                                                     text     label
# 0      प्रा . प्रताप हरिदास : होय , मला वाटते की हा ए...  com_tech
# 1      तर , विशिष्ट गोष्टींद्वारे , ठराविक कायद्यांद्...    bioche
# 2      - - - - - - - - - - - - - - - - - - - - - - - ...       cse
# 3                   तर , आपला अर्धा चिन्ह 9 वाजता असेल .       phy
# 4      म्हणून , मी असे म्हणालो की जर शेकडो , हजारो कि...       phy
# ...                                                  ...       ...
# 41992  जरी आपण डेटा कूटबद्ध केला , तरीही हा मुख्य व्य...       cse
# 41993  ते म्हणतात - " ज्याला पाहण्यासाठी डोळे , ऎकण्य...  com_tech
# 41994  प्रथम क्रोनोलॉजिकल , क्रॉनोलॉजी म्हणजे आपल्याल...  com_tech
# 41995  त्या थोड्या तपशीलावर येईल , जेणेकरून संपूर्ण ग...    bioche
# 41996  आणि एका हॉटेलमध्ये त्यांनी एका स्विस रेस्ट्राम...  com_tech
#
# [41997 rows x 2 columns]

# %%
x_train = training_data.text.apply(lambda x: obj.preprocess_data(x)).values.tolist()

# %%
y_train = training_data.label.values.tolist()

# %%
val_path = "../dataset/original-dataset/marathi-validation-data.csv"
val_data = obj.read_data(val_path)
val_data
# Out:
#                                                    text     label
# 0                                             1 ची ओळ .       cse
# 1     तर , ही एक टॉवर आहे जी टॉवरवर निश्चित केली जात...       phy
# 2     तर , थ्रेडच्या परतीच्या स्थितीस पास करण्यासाठी...       cse
# 3     आपण लोक शोधत आहात जे आपल्यासाठी काहीतरी करू शक...  com_tech
# 4     लिनक्स कर्नल अनुसूचीतकरणामध्ये अशी तंत्र असण्य...       cse
# ...                                                 ...       ...
# 3775  नंतर वृद्धत्व , व्हॉट मोठ्या प्रमाणात फ्रॉन 12...    bioche
# 3776  आणि मग सुद्धा आपल्याला काही सेकंदांनंतर माहित ...       phy
# 3777             तर , आपण ELF शीर्षलेखासह प्रारंभ करू .       cse
# 3778                     तर , त्या क्रॉस्टची जाडी आहे .       phy
# 3779  तर , मला वाटते की ही माहिती अशी आहे की आपण एका...       phy
#
# [3780 rows x 2 columns]

# %%
x_val = val_data.text.apply(lambda x: obj.preprocess_data(x)).values.tolist()
y_val = val_data.label.values.tolist()

# %% [markdown]
# # Tokenize Data

# %%
def tokenize_text(x_train, x_val):
    tokenizer = Tokenizer(oov_token='[OOV]')
    tokenizer.fit_on_texts(x_train)
    x_train_tokenized = tokenizer.texts_to_sequences(x_train)
    x_val_tokenized = tokenizer.texts_to_sequences(x_val)
    return tokenizer, x_train_tokenized, x_val_tokenized

# %%
tokenizer, x_train_tokenized, x_val_tokenized = tokenize_text(x_train, x_val)
print(len(x_train_tokenized))
print(len(x_val_tokenized))
# Out:
# 41997
# 3780

# %%
vocab = tokenizer.word_index
vocab_words = vocab.keys()

# %%
def analyze_vocab(vocab_words):
    numbers = []
    english_words = []
    marathi_words = []
    for word in vocab_words:
        if any(map(str.isdigit, word)):
        #if re.match('\d+', word):
            numbers.append(word)
        elif re.match('[a-zA-Z]+', word):
            english_words.append(word)
        else:
            marathi_words.append(word)
    return numbers, english_words, marathi_words

# %%
print("Total Vocabulary: ", len(vocab_words))
numbers, english_words, marathi_words = analyze_vocab(vocab_words)
print(len(numbers))
print(len(english_words))
print(len(marathi_words))
# Out:
# Total Vocabulary:  51801
# 0
# 909
# 50892

# %%
for word in numbers:
        print(word)
# Out:
# xv6
# x86
# r1
# r2
# co2
# p1
# ec2
# q10
# p3
# p2
# s2
# w1
# x2go
# cr3
# v1
# p4
# s1
# s3
# f1
# w2
# x1
# v2
# w3
# t1
# dom0
# x2
# a2
# ffff0
# k2
# w4
# t1z
# h2
# t2
# tio2
# rω2
# d1
# application1
# k1et
# cr0
# r3
# f210t2
# m1
# m2
# mrω2
# q1
# nσ2
# i386
# if30
# into100
# dom4j
# v2p
# p12
# d121
# eg1
# eg2
# x11
# i7
# a1
# b1
# k3
# g1
# g2
# g3
# g4
# vtrω2g
# s12
# av1
# w3c
# d2
# ec2s
# x100
# k1
# by6into100
# num1
# x68
# minus2
# y2
# p2v
# raid1
# raid2
# raid5
# logf1logf2
# logf1f2
# x7felf
# v4
# v9
# h2o
# c6h12o6
# o2
# mixtimes100
# n2σ2
# cd1
# alv1
# t15
# e210
# c4

# %%
for t, d in list(zip(x_train, training_data.text.values.tolist())):
    for w in t.split():
        if w in numbers:
            print(t)
            print(d, "\n")
# Out:
# ऑब्जेक्ट फाईल x86 #N बिट मशीन्ससाठी दर्शविते नंतर पाहिले प्रकरणात एंट्री पॉइंट #N
# तर , हा ऑब्जेक्ट फाईल x86 - 64 बिट मशीन्ससाठी आहे , हे दर्शविते , नंतर आपण पाहिले आहे की या प्रकरणात एंट्री पॉइंट 0 आहे .
#
# प्रत्यक्षात वितरण s1 वर्ग भगिले सिग्मा #N वर्ग भगिले s2 वर्ग सिग्मा #N वर्ग
# म्हणजे प्रत्यक्षात F वितरण s1 वर्ग भगिले सिग्मा 1 वर्ग भगिले s2 वर्ग सिग्मा 2 वर्ग .
#
# प्रत्यक्षात वितरण s1 वर्ग भगिले सिग्मा #N वर्ग भगिले s2 वर्ग सिग्मा #N वर्ग
# म्हणजे प्रत्यक्षात F वितरण s1 वर्ग भगिले सिग्मा 1 वर्ग भगिले s2 वर्ग सिग्मा 2 वर्ग .
#
# x86 प्रणालीमध्ये #N प्रकारचे डिस्क्रिप्टर टेबल असतात
# x86 प्रणालीमध्ये 2 प्रकारचे डिस्क्रिप्टर टेबल असतात .
#
# क्षेत्रांच्या छेदनबिंदारास चतुर्भुज चौकोन दर्शवित ज्याने संसाधन r1 विनंती करणार्या दोन्ही प्रक्रियांमध्ये निर्देशांचे अनुकरण
# म्हणून , या दोन क्षेत्रांच्या छेदनबिंदारास हे चतुर्भुज चौकोन दर्शवित आहे ज्याने संसाधन R1 विनंती करणार्या दोन्ही प्रक्रियांमध्ये निर्देशांचे अनुकरण केले आहे .
#
# q10 लक्षात ठेवा प्रक्रिया संरक्षणाच्या अधिकारानुसार लक्षात ठेवून अतिशय चांगले उदाहरण किंवा माहिती
# तर , या Q10 लक्षात ठेवा की ही प्रक्रिया आणि संरक्षणाच्या अधिकारानुसार लक्षात ठेवून हे एक अतिशय चांगले उदाहरण किंवा माहिती आहे .
#
# xv6 सेगमेंटेशनचा जास्त वापर करीत केवळ #N विभाग तयार करते
# Xv6 सेगमेंटेशनचा जास्त वापर करीत नाही , ते केवळ 4 विभाग तयार करते .
#
# अर्थाच्या बाबतीत एकूण मागणी माध्यमांमधील प्रमाणात nμ nσ2
# तर , अर्थाच्या बाबतीत एकूण मागणी , काही माध्यमांमधील काही प्रमाणात nμ , nσ2 आहे .
#
# x2go वरुन जा दाव्यावरून आपल्याला मेघमाला प्रविष्ट करावयाचे योग्यरित्या पाठविलेले व्हीएम
# म्हणून , x2go वरुन जा दाव्यावरून आपल्याला मेघमाला प्रविष्ट करावयाचे आहे जे योग्यरित्या पाठविलेले व्हीएम आहे .
#
# x2go वरुन जा दाव्यावरून आपल्याला मेघमाला प्रविष्ट करावयाचे योग्यरित्या पाठविलेले व्हीएम
# म्हणून , x2go वरुन जा दाव्यावरून आपल्याला मेघमाला प्रविष्ट करावयाचे आहे जे योग्यरित्या पाठविलेले व्हीएम आहे .
#
# तथापि प्रकरणात जिथे आमच्याकडे प्रथम s1 नंतर s3 नंतर s2 विशिष्ट प्रकरणात वाटप परवानगी कारण क्रम अनुपालन धन्यवाद
# तथापि , या प्रकरणात जिथे आमच्याकडे प्रथम S1 आहे नंतर S3 आणि नंतर S2 , म्हणून या विशिष्ट प्रकरणात वाटप  परवानगी नाही कारण क्रम अनुपालन नाही . धन्यवाद .
#
# तथापि प्रकरणात जिथे आमच्याकडे प्रथम s1 नंतर s3 नंतर s2 विशिष्ट प्रकरणात वाटप परवानगी कारण क्रम अनुपालन धन्यवाद
# तथापि , या प्रकरणात जिथे आमच्याकडे प्रथम S1 आहे नंतर S3 आणि नंतर S2 , म्हणून या विशिष्ट प्रकरणात वाटप  परवानगी नाही कारण क्रम अनुपालन नाही . धन्यवाद .
#
# तथापि प्रकरणात जिथे आमच्याकडे प्रथम s1 नंतर s3 नंतर s2 विशिष्ट प्रकरणात वाटप परवानगी कारण क्रम अनुपालन धन्यवाद
# तथापि , या प्रकरणात जिथे आमच्याकडे प्रथम S1 आहे नंतर S3 आणि नंतर S2 , म्हणून या विशिष्ट प्रकरणात वाटप  परवानगी नाही कारण क्रम अनुपालन नाही . धन्यवाद .
#
# उदाहरणार्थ एएलएफ ह्या यंत्राच्या तपशीलांमध्ये जसे i386 x86 #N एआरएम एमआयआयपी असेच असू शकतात
# उदाहरणार्थ , एएलएफ ह्या यंत्राच्या तपशीलांमध्ये जसे की i386 , x86 _ 64 , एआरएम , एमआयआयपी आणि असेच असू शकतात .
#
# उदाहरणार्थ एएलएफ ह्या यंत्राच्या तपशीलांमध्ये जसे i386 x86 #N एआरएम एमआयआयपी असेच असू शकतात
# उदाहरणार्थ , एएलएफ ह्या यंत्राच्या तपशीलांमध्ये जसे की i386 , x86 _ 64 , एआरएम , एमआयआयपी आणि असेच असू शकतात .
#
# #N अंडरस्कोर आतील फाईल पर्यंत p1 अंडरस्कोर आतील असत्याचे मूल्य असत्य अर्थ प्रक्रिया पी #N गंभीर विभागांमधून बाहेर पडला गंभीर विभागात
# P 1 अंडरस्कोर आतील फाईल पर्यंत , म्हणून p1 अंडरस्कोर आतील असत्याचे मूल्य असत्य आहे याचा अर्थ की प्रक्रिया पी 1 गंभीर विभागांमधून बाहेर पडला आहे आणि आता गंभीर विभागात नाही .
#
# जर #N मिलीलीटर कप #N मिलीफील घेतले आणखी मिश्रण if30 मिली मिश्रण #N सेंटीट मध्ये #N into100 बनते #N च्या बरोबरीने
# असेही गृहीत धरू की आपण पी 1 , पी 2 आणि पी 3 पी 4 पेक्षा जास्त किंवा इतर शब्दात P4 सर्वात कमी प्राधान्य प्रक्रिया आहे .
#
# त्यासाठी x2go नामक सॉफ्टवेअर वापरत
# तर त्यासाठी मी x2go नामक सॉफ्टवेअर वापरत आहे .
#
# dom4j सारखे लेखन नेव्हीगेशन वाचण्यासाठी एक्सएमएल संपादित करण्यासाठी जावा फ्रेमवर्क
# काही DOM4J सारखे आहेत जे लेखन नेव्हीगेशन वाचण्यासाठी आणि एक्सएमएल संपादित करण्यासाठी जावा फ्रेमवर्क आहे .
#
# ऑपरेटिंग सिस्टम किंवा कर्नल सहजपणे संबंधित भौतिक पत्त्यावर v2p ओळखल्या जाणाऱ्या मॅक्रोचा वापर किंवा भौतिक मेमरी रूपांतरण मॅक्रोवर सहजपणे प्राप्त करू शकतात
# ऑपरेटिंग सिस्टम किंवा कर्नल सहजपणे संबंधित भौतिक पत्त्यावर V2P म्हणून ओळखल्या जाणाऱ्या मॅक्रोचा वापर करून किंवा भौतिक मेमरी रूपांतरण मॅक्रोवर सहजपणे प्राप्त करू शकतात .
#
# आकृत्यापासून टीडीटी #N #N टीडीटी #N #N संबंधित तापमान t1 t2
# आकृत्यापासून , टीडीटी 2 = 1 आणि टीडीटी 1 = 10 म्हणून , संबंधित तापमान T1 आणि T2 .
#
# आकृत्यापासून टीडीटी #N #N टीडीटी #N #N संबंधित तापमान t1 t2
# आकृत्यापासून , टीडीटी 2 = 1 आणि टीडीटी 1 = 10 म्हणून , संबंधित तापमान T1 आणि T2 .
#
# x2go क्लायंट
# तर , हा x2go क्लायंट आहे .
#
# w1 मोजत मॅपरीड्यूसमधील समस्या अंतिम चर्चा किंवा शेवटचे व्याख्यान आम्ही दर्शविले सिस्टीममध्ये समांतर कार्यक्षमता देऊ शकते
# w1 . म्हणून , हे मोजत आहे की मॅपरीड्यूसमधील समस्या काय आहे आणि अंतिम चर्चा किंवा शेवटचे व्याख्यान आम्ही दर्शविले आहे की हे सिस्टीममध्ये समांतर कार्यक्षमता देऊ शकते .
#
# केळे फळ काळे सेब बटाट्या गोष्टी बर्याचदा ओततो तपकिरी रंगाच्या खाली येते आपल्याला आठवते लक्षात ठेवल्यास उदाहरण देतो मम्मी किंवा इतरांच्या मनी वरिष्ठांसाठी आपल्यासाठी तयार देव किंवा त्यासारख्या पैसे देण्यासारख्या वस्तू किंवा त्यासारख्या पैशसम गोष्टी ज्यासाठी जास्त काळ उकळत्या दुधात वेळ असतो जेव्हा तेव्हा पांढरे दूध परंतु दीर्घ काळानंतर तपकिरी बनले काहीही दिले दुधाला काहीच मिळाले अगदी इतरही म्हणूनच नॉन एंजाइमेटिक ब्राउनिंग अंतर्गत नॉन एंजाइमेटिक ब्राऊनिंगमध्ये पुन्हा प्रकार ज्याला कारमायलायझेशन म्हणतात दुसरा माइलर्ड प्रतिक्रिया कारमॅलायझेशन माइलर्ड प्रतिक्रिया खाद्य पदार्थांशी सर्वत्र संबंधित q10 जर आपल्याला आठवत असेल आम्ही q10 सांगितले नेहमीच संबद्ध क्यू #N जास्त तपमान जितका प्रतिक्रिया असतो प्रत्येक सामग्रीसाठी सत्य
एक सामान्य कल्पना आहे की आम्ही संख्या पाहिल्या आहेत की हे आपल्या कल्पनाशक्तीची कल्पना नाही ही एक वाजवी कल्पना आहे जर आपण ऊर्जा उधळत राहिलात आणि जर आपण सध्या हे करत आहोत आणि जर आपण या दोन्ही पॅरामीटर्स  बरोबर एकत्रित केले तर उर्जेचे स्त्रोत समान आहे , आपण जर झाडे तोडली तर वातावरणात सीओ 2 वर चढत राहील हे अगदी अपरिहार्य आहे .
#
# अर्थ p12 p3 नावाचे काहीतरी होऊ शकते p3 मध्ये इनपुट असू शकते p3 p4 अंतर्भूत केल्यामुळे गोष्टींच्या अंतिम परिणामासह बाहेर येईल
# तर , याचा अर्थ असा आहे की P12 म्हणजे P3 नावाचे काहीतरी होऊ शकते जे P3 मध्ये इनपुट असू शकते आणि P3 आणि P4 अंतर्भूत केल्यामुळे गोष्टींच्या अंतिम परिणामासह बाहेर येईल .
#
# अर्थ p12 p3 नावाचे काहीतरी होऊ शकते p3 मध्ये इनपुट असू शकते p3 p4 अंतर्भूत केल्यामुळे गोष्टींच्या अंतिम परिणामासह बाहेर येईल
# तर , याचा अर्थ असा आहे की P12 म्हणजे P3 नावाचे काहीतरी होऊ शकते जे P3 मध्ये इनपुट असू शकते आणि P3 आणि P4 अंतर्भूत केल्यामुळे गोष्टींच्या अंतिम परिणामासह बाहेर येईल .
#
# अर्थ p12 p3 नावाचे काहीतरी होऊ शकते p3 मध्ये इनपुट असू शकते p3 p4 अंतर्भूत केल्यामुळे गोष्टींच्या अंतिम परिणामासह बाहेर येईल
# तर , याचा अर्थ असा आहे की P12 म्हणजे P3 नावाचे काहीतरी होऊ शकते जे P3 मध्ये इनपुट असू शकते आणि P3 आणि P4 अंतर्भूत केल्यामुळे गोष्टींच्या अंतिम परिणामासह बाहेर येईल .
#
# अर्थ p12 p3 नावाचे काहीतरी होऊ शकते p3 मध्ये इनपुट असू शकते p3 p4 अंतर्भूत केल्यामुळे गोष्टींच्या अंतिम परिणामासह बाहेर येईल
# तर , याचा अर्थ असा आहे की P12 म्हणजे P3 नावाचे काहीतरी होऊ शकते जे P3 मध्ये इनपुट असू शकते आणि P3 आणि P4 अंतर्भूत केल्यामुळे गोष्टींच्या अंतिम परिणामासह बाहेर येईल .
#
# अर्थ p12 p3 नावाचे काहीतरी होऊ शकते p3 मध्ये इनपुट असू शकते p3 p4 अंतर्भूत केल्यामुळे गोष्टींच्या अंतिम परिणामासह बाहेर येईल
# तर , याचा अर्थ असा आहे की P12 म्हणजे P3 नावाचे काहीतरी होऊ शकते जे P3 मध्ये इनपुट असू शकते आणि P3 आणि P4 अंतर्भूत केल्यामुळे गोष्टींच्या अंतिम परिणामासह बाहेर येईल .
#
# r1 r2
# R1 आणि R2 .
#
# r1 r2
# R1 आणि R2 .
#
# प्रतीक्षा प्रणाली कॉलच्या आंतरिक बाबींबद्दल जाणून घेऊ xv6 ऑपरेटिंग सिस्टमच्या संदर्भात गेलेले विशेष प्रवाहकार्ड
# आता , प्रतीक्षा प्रणाली कॉलच्या आंतरिक बाबींबद्दल जाणून घेऊ या , म्हणजे xv6 ऑपरेटिंग सिस्टमच्या संदर्भात केले गेलेले हे विशेष प्रवाहकार्ड .
#
# उदाहरणार्थ xv6 मध्ये जर विशिष्ट हेडर फाइल्सची तपासणी आपल्याला विविध सिस्टम कॉल नंबर नमूद होतील
# उदाहरणार्थ , xv6 मध्ये , जर आपण या विशिष्ट हेडर फाइल्सची तपासणी केली तर आपल्याला विविध सिस्टम कॉल नंबर नमूद होतील .
#
# जर कुठल्याही ठिकाणी कार्बन मोनोऑक्साइड प्रदूषित असेल कार्बननेट इंधन सेलमध्ये वितरीत असेल प्रत्यक्षात स्वच्छ करू शकता केवळ co2 ओकेमध्ये रूपांतरित करेल
# जर आपण कुठल्याही ठिकाणी कार्बन मोनोऑक्साइड प्रदूषित केले असेल आणि आपण ते कार्बननेट इंधन सेलमध्ये वितरीत केले असेल तर आपण ते प्रत्यक्षात स्वच्छ करू शकता आणि ते केवळ CO2 ओकेमध्ये रूपांतरित करेल .
#
# ti साठी #N आपल्याला हवे असेल तिथे tio2 #N इलेक्ट्रॉन व्हॉल्टर ठेवू
# तर , Ti साठी 3.2 आहे तर आपल्याला हवे असेल तर मी तिथे TiO2 , 3.2 इलेक्ट्रॉन व्हॉल्टर ठेवू .
#
# जर टीडीटी लाइनसाठी ढलप बघत आहोत log t1
# जर आपण टीडीटी लाइनसाठी हे ढलप बघत आहोत तर - - log⁡  2T2 - T1 आहे .
#
# फक्त x86 सिस्टीममध्ये आठवायचे असेल मेमरी ट्रान्सलेशनचे स्तर
# आता फक्त x86 सिस्टीममध्ये आठवायचे असेल तर मेमरी ट्रान्सलेशनचे दोन स्तर आहेत .
#
# म्हणते मध्ये w1 w2 w1 जसे #N w2 काहीतरी #N
# तर , ते म्हणते की w मध्ये w1 , w2 , म्हणून w1 , जसे 7 , w2 काहीतरी 15 आहे .
#
# म्हणते मध्ये w1 w2 w1 जसे #N w2 काहीतरी #N
# तर , ते म्हणते की w मध्ये w1 , w2 , म्हणून w1 , जसे 7 , w2 काहीतरी 15 आहे .
#
# म्हणते मध्ये w1 w2 w1 जसे #N w2 काहीतरी #N
# तर , ते म्हणते की w मध्ये w1 , w2 , म्हणून w1 , जसे 7 , w2 काहीतरी 15 आहे .
#
# म्हणते मध्ये w1 w2 w1 जसे #N w2 काहीतरी #N
# तर , ते म्हणते की w मध्ये w1 , w2 , म्हणून w1 , जसे 7 , w2 काहीतरी 15 आहे .
#
# सह निवासी तपासणी dom0 ची ओळख प्रतिबंधित करते कदाचित असू शकते
# म्हणून , सह - निवासी तपासणी dom0 ची ओळख प्रतिबंधित करते जे कदाचित एक असू शकते .
#
# त्यासाठी x2go नामक सॉफ्टवेअर वापरत
# तर त्यासाठी मी x2go नामक सॉफ्टवेअर वापरत आहे .
#
# init dot कोड बघूया xv6 चा भाग
# आता आपण init dot c हा कोड बघूया जो xv6 चा भाग आहे .
#
# समजा प्रोसेस p1 सीपीयूमध्ये कार्यान्वित करते लॉक #N च्या बरोबरीने कार्यान्वित करते तेव्हा आपल्याकडे #N लॉक
# समजा प्रोसेस P1 सीपीयूमध्ये कार्यान्वित करते आणि लॉक 0 च्या बरोबरीने कार्यान्वित करते , तेव्हा आपल्याकडे येथे 0 म्हणून लॉक आहे .
#
# संदर्भ स्विच प्रक्रिया p2 कार्यान्वित करते
# आता , हा संदर्भ स्विच प्रक्रिया P2 कार्यान्वित करते .
#
# xv6 कर्नल स्पेसमध्ये मॅपिंग रॅममधे मॅपिंग करण्यामध्ये समाविष्ट पद्धतींचा क्रम पाहू
# xv6 कर्नल स्पेसमध्ये मॅपिंग रॅममधे मॅपिंग करण्यामध्ये समाविष्ट असलेल्या पद्धतींचा क्रम पाहू .
#
# जर तापमान कमी असेल तर उत्पादन चांगले असेल की Q10 थेट येथे येत आहे .
#
# r1 प्लस #N बरोबर दुसरी ओळ r1 असेल नंतर r1 मेमरीमध्ये परत येईल
# म्हणजे ती R1 प्लस 1 बरोबर दुसरी ओळ R1 असेल आणि नंतर R1 मेमरीमध्ये परत येईल .
#
# r1 प्लस #N बरोबर दुसरी ओळ r1 असेल नंतर r1 मेमरीमध्ये परत येईल
# म्हणजे ती R1 प्लस 1 बरोबर दुसरी ओळ R1 असेल आणि नंतर R1 मेमरीमध्ये परत येईल .
#
# r1 प्लस #N बरोबर दुसरी ओळ r1 असेल नंतर r1 मेमरीमध्ये परत येईल
# म्हणजे ती R1 प्लस 1 बरोबर दुसरी ओळ R1 असेल आणि नंतर R1 मेमरीमध्ये परत येईल .
#
# आवश्यक नसलेल्या पॅकेजेस काढा जसे मला x11 किंवा विंडोज मॅनेजर इत्यादि इत्यादिची गरज
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - आवश्यक नसलेल्या सर्व पॅकेजेस काढा ; जसे की मला X11 किंवा विंडोज मॅनेजर इत्यादि इत्यादिची गरज नाही .
#
# तेव्हाच वापरलेले #N आधारित प्रोसेसर आजही इंटेलमधील नवीनतम i7 प्रोसेसरवर कार्यरत
# तेव्हाच वापरलेले 386 आधारित प्रोसेसर आजही इंटेलमधील नवीनतम i7 प्रोसेसरवर कार्यरत आहेत .
#
# आपल्याला सीओ #N मिळत असल्याने आपल्याला आणखी co2 देखील मिळतील नंतर दोन्ही प्रक्रियेमध्ये इलेक्ट्रॉन्स सोडल्या जातील
# तर , आपल्याला हे सीओ 2  मिळत असल्याने येथे आपल्याला आणखी काही CO2 देखील मिळतील आणि नंतर या दोन्ही प्रक्रियेमध्ये इलेक्ट्रॉन्स सोडल्या जातील .
#
# नंतर p1 खालील अंडरस्कोर सत्य बरोबर #N अंडरस्कोर खालील true हिरव्या रंगात प्रक्रिया #N शी संबंधित
# नंतर p1 खालील अंडरस्कोर तर सत्य बरोबर आहे आणि p 2 अंडरस्कोर खालील true आहे , तर हे हिरव्या रंगात आहे , म्हणून ती प्रक्रिया 2 शी संबंधित आहे .
#
# प्रसरण #N घेता सिग्मा वर्ग एवढा जेव्हा तुम्हाला x1 भागीले #N प्रसरण मिळते तेव्हा सिग्मा वर्ग भागीले वर्ग बदलते तुम्हाला आठवतं bar ची व्याख्या x1 x2 xn भागीले
# आपण प्रसरण x 1 घेता जो सिग्मा वर्ग एवढा आहे पण जेव्हा तुम्हाला x1 भागीले 1 प्रसरण मिळते तेव्हा ते सिग्मा वर्ग भागीले n वर्ग असे बदलते , तुम्हाला आठवतं की x bar ची व्याख्या आपण x1 अधिक x2 अधिक xn भागीले n अशी केली .
#
# प्रसरण #N घेता सिग्मा वर्ग एवढा जेव्हा तुम्हाला x1 भागीले #N प्रसरण मिळते तेव्हा सिग्मा वर्ग भागीले वर्ग बदलते तुम्हाला आठवतं bar ची व्याख्या x1 x2 xn भागीले
ंतु अंमलबजावणीची वेळ मोठ्या प्रमाणावर भिन्न असू शकते बरोबर जसे माझ्याकडे #N प्रचंड डेटा बेस जसे r1 रिलायंस डेटाबेस r1 r2 प्रोजेक्शन किंवा निवड करतो गोष्टी a1 a2 निवडतो नंतर करू शकतो करू समजू नका अशा गोष्टी बनविण्यापूर्वी किंवा नंतर सामील होईन सामील r1 वर निवड केल्यास #N लाखांहून टुप्स होण्यास सांगतात
# म्हणून , जर हा आपल्यासारखा मोठा डेटा बेस असेल तर आपण निवडण्यापूर्वी किंवा नंतर निवड निवडण्यापूर्वी प्रोजेक्ट करू शकता की त्यामध्ये खूप फरक पडतो ; जरी क्वेरी एकसारखी असली तरी क्वेरी आउटपुट एकसारख्याच असतील , परंतु अंमलबजावणीची वेळ मोठ्या प्रमाणावर भिन्न असू शकते , बरोबर , जसे माझ्याकडे 2 प्रचंड डेटा बेस आहेत जसे R1 म्हणजे रिलायंस डेटाबेस R1 , R2 आणि मी काही प्रोजेक्शन किंवा निवड करतो काही गोष्टी , मी A1 , A2 निवडतो आणि नंतर करू शकतो ; मग करू ; समजू नका अशा गोष्टी बनविण्यापूर्वी किंवा नंतर मी सामील होईन की नाही हे मी सामील आहे ; मी R1 वर निवड केल्यास ; 1 लाखांहून कमी टुप्स कमी होण्यास सांगतात .
#
# जर आपल्यासारखा मोठा डेटा बेस असेल निवडण्यापूर्वी किंवा नंतर निवड निवडण्यापूर्वी प्रोजेक्ट करू शकता त्यामध्ये खूप फरक पडतो क्वेरी एकसारखी असली क्वेरी आउटपुट एकसारख्याच असतील परंतु अंमलबजावणीची वेळ मोठ्या प्रमाणावर भिन्न असू शकते बरोबर जसे माझ्याकडे #N प्रचंड डेटा बेस जसे r1 रिलायंस डेटाबेस r1 r2 प्रोजेक्शन किंवा निवड करतो गोष्टी a1 a2 निवडतो नंतर करू शकतो करू समजू नका अशा गोष्टी बनविण्यापूर्वी किंवा नंतर सामील होईन सामील r1 वर निवड केल्यास #N लाखांहून टुप्स होण्यास सांगतात
# म्हणून , जर हा आपल्यासारखा मोठा डेटा बेस असेल तर आपण निवडण्यापूर्वी किंवा नंतर निवड निवडण्यापूर्वी प्रोजेक्ट करू शकता की त्यामध्ये खूप फरक पडतो ; जरी क्वेरी एकसारखी असली तरी क्वेरी आउटपुट एकसारख्याच असतील , परंतु अंमलबजावणीची वेळ मोठ्या प्रमाणावर भिन्न असू शकते , बरोबर , जसे माझ्याकडे 2 प्रचंड डेटा बेस आहेत जसे R1 म्हणजे रिलायंस डेटाबेस R1 , R2 आणि मी काही प्रोजेक्शन किंवा निवड करतो काही गोष्टी , मी A1 , A2 निवडतो आणि नंतर करू शकतो ; मग करू ; समजू नका अशा गोष्टी बनविण्यापूर्वी किंवा नंतर मी सामील होईन की नाही हे मी सामील आहे ; मी R1 वर निवड केल्यास ; 1 लाखांहून कमी टुप्स कमी होण्यास सांगतात .
#
# जर आपल्यासारखा मोठा डेटा बेस असेल निवडण्यापूर्वी किंवा नंतर निवड निवडण्यापूर्वी प्रोजेक्ट करू शकता त्यामध्ये खूप फरक पडतो क्वेरी एकसारखी असली क्वेरी आउटपुट एकसारख्याच असतील परंतु अंमलबजावणीची वेळ मोठ्या प्रमाणावर भिन्न असू शकते बरोबर जसे माझ्याकडे #N प्रचंड डेटा बेस जसे r1 रिलायंस डेटाबेस r1 r2 प्रोजेक्शन किंवा निवड करतो गोष्टी a1 a2 निवडतो नंतर करू शकतो करू समजू नका अशा गोष्टी बनविण्यापूर्वी किंवा नंतर सामील होईन सामील r1 वर निवड केल्यास #N लाखांहून टुप्स होण्यास सांगतात
# म्हणून , जर हा आपल्यासारखा मोठा डेटा बेस असेल तर आपण निवडण्यापूर्वी किंवा नंतर निवड निवडण्यापूर्वी प्रोजेक्ट करू शकता की त्यामध्ये खूप फरक पडतो ; जरी क्वेरी एकसारखी असली तरी क्वेरी आउटपुट एकसारख्याच असतील , परंतु अंमलबजावणीची वेळ मोठ्या प्रमाणावर भिन्न असू शकते , बरोबर , जसे माझ्याकडे 2 प्रचंड डेटा बेस आहेत जसे R1 म्हणजे रिलायंस डेटाबेस R1 , R2 आणि मी काही प्रोजेक्शन किंवा निवड करतो काही गोष्टी , मी A1 , A2 निवडतो आणि नंतर करू शकतो ; मग करू ; समजू नका अशा गोष्टी बनविण्यापूर्वी किंवा नंतर मी सामील होईन की नाही हे मी सामील आहे ; मी R1 वर निवड केल्यास ; 1 लाखांहून कमी टुप्स कमी होण्यास सांगतात .
#
# जर आपल्यासारखा मोठा डेटा बेस असेल निवडण्यापूर्वी किंवा नंतर निवड निवडण्यापूर्वी प्रोजेक्ट करू शकता त्यामध्ये खूप फरक पडतो क्वेरी एकसारखी असली क्वेरी आउटपुट एकसारख्याच असतील परंतु अंमलबजावणीची वेळ मोठ्या प्रमाणावर भिन्न असू शकते बरोबर जसे माझ्याकडे #N प्रचंड डेटा बेस जसे r1 रिलायंस डेटाबेस r1 r2 प्रोजेक्शन किंवा निवड करतो गोष्टी a1 a2 निवडतो नंतर करू शकतो करू समजू नका अशा गोष्टी बनविण्यापूर्वी किंवा नंतर सामील होईन सामील r1 वर निवड केल्यास #N लाखांहून टुप्स होण्यास सांगतात
# म्हणून , जर हा आपल्यासारखा मोठा डेटा बेस असेल तर आपण निवडण्यापूर्वी किंवा नंतर निवड निवडण्यापूर्वी प्रोजेक्ट करू शकता की त्यामध्ये खूप फरक पडतो ; जरी क्वेरी एकसारखी असली तरी क्वेरी आउटपुट एकसारख्याच असतील , परंतु अंमलबजावणीची वेळ मोठ्या प्रमाणावर भिन्न असू शकते , बरोबर , जसे माझ्याकडे 2 प्रचंड डेटा बेस आहेत जसे R1 म्हणजे रिलायंस डेटाबेस R1 , R2 आणि मी काही प्रोजेक्शन किंवा निवड करतो काही गोष्टी , मी A1 , A2 निवडतो आणि नंतर करू शकतो ; मग करू ; समजू नका अशा गोष्टी बनविण्यापूर्वी किंवा नंतर मी सामील होईन की नाही हे मी सामील आहे ; मी R1 वर निवड केल्यास ; 1 लाखांहून कमी टुप्स कमी होण्यास सांगतात .
#
# जर आपल्यासारखा मोठा डेटा बेस असेल निवडण्यापूर्वी किंवा नंतर निवड निवडण्यापूर्वी प्रोजेक्ट करू शकता त्यामध्ये खूप फरक पडतो क्वेरी एकसारखी असली क्वेरी आउटपुट एकसारख्याच असतील परंतु अंमलबजावणीची वेळ मोठ्या प्रमाणावर भिन्न असू शकते बरोबर जसे माझ्याकडे #N प्रचंड डेटा बेस जसे r1 रिलायंस डेटाबेस r1 r2 प्रोजेक्शन किंवा निवड करतो गोष्टी a1 a2 निवडतो नंतर करू शकतो करू समजू नका अशा गोष्टी बनविण्यापूर्वी किंवा नंतर सामील होईन सामील r1 वर निवड केल्यास #N लाखांहून टुप्स होण्यास सांगतात
# म्हणून , जर हा आपल्यासारखा मोठा डेटा बेस असेल तर आपण निवडण्यापूर्वी किंवा नंतर निवड निवडण्यापूर्वी प्रोजेक्ट करू शकता की त्यामध्ये खूप फरक पडतो ; जरी क्वेरी एकसारखी असली तरी क्वेरी आउटपुट एकसारख्याच असतील , परंतु अंमलबजावणीची वेळ मोठ्या प्रमाणावर भिन्न असू शकते , बरोबर , जसे माझ्याकडे 2 प्रचंड डेटा बेस आहेत जसे R1 म्हणजे रिलायंस डेटाबेस R1 , R2 आणि मी काही प्रोजेक्शन किंवा निवड करतो काही गोष्टी , मी A1 , A2 निवडतो आणि नंतर करू शकतो ; मग करू ; समजू नका अशा गोष्टी बनविण्यापूर्वी किंवा नंतर मी सामील होईन की नाही हे मी सामील आहे ; मी R1 वर निवड केल्यास ; 1 लाखांहून कमी टुप्स कमी होण्यास सांगतात .
#
# पुढे xv6 unix version #N सारखे डिझाइन करण्यासाठी डिझाइन
# पुढे , xv6 हे UNIX version 6 सारखे डिझाइन करण्यासाठी डिझाइन केले आहे .
#
# बल लहान व्ही व्ही #N #N वॅन्स व्ही #N च्या समान केवळ वेगाने बदल गतिमान बदलाच्या दराकडे पाहिल्यास दुसर्या भागाची शक्ती असल्याचेही आम्ही पाहिले उर्जेच्या संरक्षणातून आम्हाला शक्ती मिळाली अर्धा rho av #N चौरस वजा v2 स्क्वेअर उजवीकडे
# तर , बल एक लहान व्ही व्ही 1 1 वॅन्स व्ही 2 च्या समान आहे आणि केवळ वेगाने बदल आणि गतिमान बदलाच्या दराकडे पाहिल्यास आणि दुसर्या भागाची शक्ती असल्याचेही आम्ही पाहिले , तर उर्जेच्या संरक्षणातून आम्हाला शक्ती मिळाली येथे अर्धा rho AV 1 चौरस वजा V2 स्क्वेअर  उजवीकडे आहे .
#
# वायू वातावरणात ठेवत आहात co2 पेक्षाही हानिकारक असू शकते झाडांपासून
# तर , हे असे वायू आहेत जे आपण वातावरणात ठेवत आहात जे CO2 पेक्षाही अधिक हानिकारक असू शकते आणि ते सर्व झाडांपासून येत आहेत .
#
# म्हणूनच मेघमध्ये लक्ष्य कुठे समजून घेण्यासाठी ec2 सेवेचे नकाशे तयार करण्याचा प्रयत्न किंवा त्यांनी दर्शविलेले दर्शविण्याची गरज
# म्हणूनच , मेघमध्ये लक्ष्य कुठे आहे हे समजून घेण्यासाठी EC2 सेवेचे नकाशे तयार करण्याचा प्रयत्न केला आहे किंवा त्यांनी दर्शविलेले दर्शविण्याची गरज आहे .
#
# b1 चे true values #N #N #N बी #N बी #N अनुक्रमे #N #N अंदाज दोन्ही बाबतीत फार जवळ परंतु अंदाजांमधील मानक त्रुटी पाहताना फरक येतो
# B1 चे true values ​​5 आणि b 0 आहे 2 ; बी 1 आणि बी 0 अनुक्रमे 5 आणि 2 आहेत आणि अंदाज दोन्ही बाबतीत फार जवळ आहेत , परंतु या अंदाजांमधील मानक त्रुटी पाहताना आपण फरक येतो .
#
# पुन्हा म्हटल्याप्रमाणे यीस्ट परत येतो q10 #N शहाणे उदाहरण देते प्रतिनिधी संख्या
# मग मी पुन्हा म्हटल्याप्रमाणे यीस्ट परत येतो की असे एक असे आहे जे की Q10 , 2 शहाणे उदाहरण देते जे प्रतिनिधी संख्या आहे .
#
# परिणामी प्राथमिक सूचना किंवा अंमलात आणलेल्या पहिल्या सूचनांचे पत्ता ffff0 मध्ये उपस्थित असतील
# परिणामी प्राथमिक सूचना किंवा अंमलात आणलेल्या पहिल्या सूचनांचे पत्ता ffff0 मध्ये उपस्थित असतील .
#
# आम्ही गृहीत धरू प्रत्येक #N चक्र विशिष्ट क्रम पुनरावृत्ती प्रोसेसरच्या #N व्या चक्रानंतर पी #N पुन्हा येईल पी #N पुन्हा येईल पी #N याचप्रकारे p4 दिसतात प्रक्रियांची क्रमाने तयार राज्य सतत येण्यासाठी अमर्यादितपणे पाहतो जर गॅन्ट चार्ट पाहत असाल प्राधान्य पी #N पी #N पी #N वर अवलंबून राहणार
# आम्ही हे गृहीत धरू या की प्रत्येक 15 चक्र हे विशिष्ट क्रम पुनरावृत्ती होते , हे प्रोसेसरच्या 15 व्या चक्रानंतर होते , पी 1 पुन्हा येईल , पी 2 पुन्हा येईल , पी 3 आणि याचप्रकारे P4 दिसतात , म्हणून प्रक्रियांची क्रमाने तयार राज्य सतत येण्यासाठी अमर्यादितपणे तर आपण जे पाहतो ते , जर आपण गॅन्ट चार्ट पाहत असाल तर प्राधान्य पी 1 , पी 2 आणि पी 3 वर अवलंबून राहणार आहे .
#
# संभाव्य लक्ष्य क्लाउडमध्ये कुठे स्थित समजून घेण्यासाठी ec2 सेवा नकाशा करा
# आणि संभाव्य लक्ष्य क्लाउडमध्ये कुठे स्थित आहेत हे समजून घेण्यासाठी EC2 सेवा नकाशा करा .
#
# xv6 मध्ये ptable ओळखली जाणारी रचना परिभाषित
# तर , xv6 मध्ये ptable म्हणून ओळखली जाणारी रचना परिभाषित केली आहे .
#
# x86 मध्ये प्रोग्राम स्टेटमध्ये रजिस्टर्स असतात जसे एसएस रजिस्टर स्टॅक सेगमेंट स्टॅक पॉइंटर फ्लॅग रजिस्टर कोड सेगमेंट निर्देश पॉइंटर
# तर , x86 मध्ये प्रोग्राम स्टेटमध्ये अनेक रजिस्टर्स असतात जसे एसएस रजिस्टर जे स्टॅक सेगमेंट , स्टॅक पॉइंटर , फ्लॅग रजिस्टर , कोड सेगमेंट आणि निर्देश पॉइंटर आहे .
#
# जसे सिस्टम कॉल्स बघतो तेव्हा xv6 च्या बाबतीत int #N सूचना वापरून कर्नलची विनंती करतो
# म्हणून , जसे की आपण सिस्टम कॉल्स बघतो तेव्हा xv6 च्या बाबतीत INT 64 सूचना वापरून कर्नलची विनंती करतो .
#
# intel सिस्टममध्ये पीटीपीआर किंवा पेज टेबल पॉइंटर रजिस्टरला cr3 रजिस्टर म्हणतात
# तर , Intel सिस्टममध्ये या पीटीपीआर किंवा पेज टेबल पॉइंटर रजिस्टरला CR3 रजिस्टर म्हणतात .
#
# आठवत xv6 embryo मध्ये नवीन प्रक्रिया अद्याप अंमलात आणण्यासाठी तयार सेट केलेली नवीन बाल प्रक्रियेसाठी पीआयडी
# म्हणून , आठवत आहे की xv6 EMBRYO मध्ये अशी एक नवीन प्रक्रिया आहे जी अद्याप अंमलात आणण्यासाठी तयार नाही , तसेच सेट केलेली आहे ती नवीन बाल प्रक्रियेसाठी पीआयडी आहे .
#
# त्याचप्रमाणे दुसरा ध्वज p1 inside
# त्याचप्रमाणे , दुसरा ध्वज p1 _ inside आहे .
#
# प्रक्रिया #N विशिष्ट वेळेस संसाधन r1 ची आवश्यकता
# तर , प्रक्रिया 1 या विशिष्ट वेळेस संसाधन R1 ची आवश्यकता आहे .
#
# त्याचप्रकारे प्रक्रिया चक्र #N चक्रक्रांतीमध्ये प्रवेश करतो प्रक्रिया p1 #N पूर्ण झाल्यावरच कार्यान्वित
# त्याचप्रकारे , प्रक्रिया चक्र 3 जो चक्रक्रांतीमध्ये प्रवेश करतो ती प्रक्रिया P1 आणि P 2 पूर्ण झाल्यावरच कार्यान्वित होते .
#
# ec2 सार्वजनिक आयपी उपसर्गांमध्ये विशिष्ट लेखांद्वारे सूचित केलेल्या ट्यून्सचे सार्वजनिक आयपी बाह्य आयपी शोधतात पोर्ट #N वर टीसीपी स्कॅन नंतर पाहतात ips प्रतिसाद देतात
# EC2 सार्वजनिक आयपी या उपसर्गांमध्ये आहेत आणि विशिष्ट लेखांद्वारे सूचित केलेल्या ट्यून्सचे सार्वजनिक आयपी जे बाह्य आयपी शोधतात ते पोर्ट 80 वर टीसीपी  स्कॅन केले आणि नंतर ते पाहतात की IPs काय प्रतिसाद देतात .
#
# max आकार xv6 नामांकन मधून येते
# हे MAX आकार xv6 नामांकन मधून येते .
#
# r1 परत काउंटरच्या व्हॅल्यूवर जाते मेमरीमध्ये साठवले जाते
# म्हणून , R1 परत काउंटरच्या व्हॅल्यूवर जाते जे मेमरीमध्ये साठवले जाते .
#
# दुसर्या शब्दात सांगायचे जर अज्ञात अवास्तव तत्वांवर वेगळ्या उदाहरणे वेळेत #N k2 k3 मध्ये लक्षात घ्या फक्त नमूना डेटा
# दुसर्या शब्दात सांगायचे तर जर मी अज्ञात - तीन अवास्तव - या तीन तत्वांवर - एका वेगळ्या उदाहरणे - वेळेत k 1 , k2 , k3 मध्ये , लक्षात घ्या की फक्त नमूना डेटा आहे .
#
# दुसर्या शब्दात सांगायचे जर अज्ञात अवास्तव तत्वांवर वेगळ्या उदाहरणे वेळेत #N k2 k3 मध्ये लक्षात घ्या फक्त नमूना डेटा
# दुसर्या शब्दात सांगायचे तर जर मी अज्ञात - तीन अवास्तव - या तीन तत्वांवर - एका वेगळ्या उदाहरणे - वेळेत k 1 , k2 , k3 मध्ये , लक्षात घ्या की फक्त नमूना डेटा आहे .
#
# d1 बाय डी #N स्प्रिंगनेस
# तर , D1 बाय डी 1 हे स्प्रिंगनेस आहे .
#
# मूलभूतपणे कसे संचयित जातात elf प्रतिमांमधील विविध घटक कसे पाहण्यासाठी xv6 os मध्ये exec सिस्टीम कॉल कसे लागू पाहण्यासाठी सज्ज
# मूलभूतपणे ते कसे संचयित केले जातात आणि ELF प्रतिमांमधील विविध घटक कसे आहेत ते पाहण्यासाठी आपण xv6 OS मध्ये exec सिस्टीम कॉल कसे लागू केले आहे हे पाहण्यासाठी सज्ज आहेत .
#
# r1 नंतर r1 #N ने वाढत
# म्हणजे R1 आणि नंतर R1 1 ने वाढत आहे .
#
# r1 नंतर r1 #N ने वाढत
# म्हणजे R1 आणि नंतर R1 1 ने वाढत आहे .
#
# गॅझेटची श्रृंखला असलेली स्टॅक ओव्हरफ्लो करणार स्टॅकमध्ये g1 नंतर g2 g3 g4 समाविष्ट
# तर , ते गॅझेटची एक श्रृंखला असलेली स्टॅक ओव्हरफ्लो करणार आहेत , त्यामुळे स्टॅकमध्ये G1 नंतर G2 , G3 आणि G4 समाविष्ट होणार आहे .
#
# गॅझेटची श्रृंखला असलेली स्टॅक ओव्हरफ्लो करणार स्टॅकमध्ये g1 नंतर g2 g3 g4 समाविष्ट
# तर , ते गॅझेटची एक श्रृंखला असलेली स्टॅक ओव्हरफ्लो करणार आहेत , त्यामुळे स्टॅकमध्ये G1 नंतर G2 , G3 आणि G4 समाविष्ट होणार आहे .
#
# गॅझेटची श्रृंखला असलेली स्टॅक ओव्हरफ्लो करणार स्टॅकमध्ये g1 नंतर g2 g3 g4 समाविष्ट
# तर , ते गॅझेटची एक श्रृंखला असलेली स्टॅक ओव्हरफ्लो करणार आहेत , त्यामुळे स्टॅकमध्ये G1 नंतर G2 , G3 आणि G4 समाविष्ट होणार आहे .
#
# गॅझेटची श्रृंखला असलेली स्टॅक ओव्हरफ्लो करणार स्टॅकमध्ये g1 नंतर g2 g3 g4 समाविष्ट
# तर , ते गॅझेटची एक श्रृंखला असलेली स्टॅक ओव्हरफ्लो करणार आहेत , त्यामुळे स्टॅकमध्ये G1 नंतर G2 , G3 आणि G4 समाविष्ट होणार आहे .
#
# यामध्ये आपणास त्वरित वेग मिळतो टर्मिनल वेग त्वरित वेग vtrω2g जिथे व्हीटी कणांचा टर्मिनल वेग आर रोटेशनच्या अक्षापासून अंतर कोनीय वेग
# यामध्ये आपणास त्वरित वेग मिळतो , येथे टर्मिनल वेग होता हा त्वरित वेग आहे जो v = vTrω2g आहे जिथे व्हीटी  हा कणांचा टर्मिनल वेग आहे , आर रोटेशनच्या अक्षापासून अंतर आहे आणि ω हा कोनीय वेग आहे .
#
# xv6 चार अशा विभागांची व्याख्या करते
# म्हणून , xv6 चार अशा विभागांची व्याख्या करते .
#
# मीटर लहान खाते नियंत्रण victim probe च्या प्रत्येक जोडी साठी dom0 पत्त्याची आवश्यकता तपासा
# तर , तीन m मीटर एक लहान खाते नियंत्रण victim probe च्या प्रत्येक जोडी A B साठी dom0 पत्त्याची आवश्यकता काय आहे ते तपासा .
#
# #N टक्के जास्त किंवा #N सीओ #N किंवा #N सारखे असू शकत प्रमाणात संख्या ऊर्जा मिळवण्यासाठी मोठ्या प्रमाणात co2 सोडल्या जाणार
# तर , 60 टक्के जास्त किंवा 60 % अधिक सीओ 2 किंवा काही असे काही 60 % सारखे असू शकत नाही काही प्रमाणात ही संख्या कमी ऊर्जा मिळवण्यासाठी काही मोठ्या प्रमाणात CO2 सोडल्या जाणार आहेत .
#
# बाह्य चौकशी ec2 च्या बाहेरच्या प्रणालीमधून उद्भवलेली चौकशी गंतव्य ec2 उदाहरण बाह्य असू शकते
# म्हणून , बाह्य चौकशी , EC2 च्या बाहेरच्या प्रणालीमधून उद्भवलेली चौकशी आणि गंतव्य म्हणून EC2 उदाहरण आहे , जे बाह्य असू शकते .
#
# बाह्य चौकशी ec2 च्या बाहेरच्या प्रणालीमधून उद्भवलेली चौकशी गंतव्य ec2 उदाहरण बाह्य असू शकते
# म्हणून , बाह्य चौकशी , EC2 च्या बाहेरच्या प्रणालीमधून उद्भवलेली चौकशी आणि गंतव्य म्हणून EC2 उदाहरण आहे , जे बाह्य असू शकते .
#
# मूलत #N चे मूल्य काउंटरला r2 मध्ये लोड जाते r2 ने #N
# त्यामुळे मूलत : 5 चे मूल्य असलेल्या काउंटरला R2 मध्ये लोड केले जाते , म्हणून R2 ने 5 केले आहे .
# उदाहरणार्थ , आम्हाला असे म्हणायला लावू या की s12 , s2 आणि s3 वाढत असलेल्या क्रमवारीत अग्रक्रमाने आहे कारण S3 सर्वोच्च प्राधान्य आहे , तर s1 सर्वात कमी प्राधान्य आहे .
#
# xv6 मध्ये विभागातील वर्णनकर्त्यास ऑपरेटिंग सिस्टम कोडमधील संरचनेत प्रस्तुत जाते
# त्यामुळे xv6 मध्ये , या विभागातील वर्णनकर्त्यास ऑपरेटिंग सिस्टम कोडमधील संरचनेत प्रस्तुत केले जाते .
#
# xv6 प्रोग्राम कार्यक्रम टाइमर प्रत्येक #N मिलीसेकंदमध्ये व्यत्यय आणतात
# तर , xv6 प्रोग्राम , कार्यक्रम टाइमर प्रत्येक 10 मिलीसेकंदमध्ये व्यत्यय आणतात .
#
# आम्ही समस्येकडे दुर्लक्ष केल्यास हळूहळू काहीतरी करू नये उत्पादन co2 नियंत्रित करू शकत म्हणूनच निसर्गास समजू शकतो निसर्गाशी सुसंगत राहू शकतो म्हणूनच निसर्गाला निसटू द्यावे म्हणूनच निसर्ग आपल्याला बंद करतो सीओ #N खाली येईल ग्लोबल वार्मिंग खाली येईल
# तर , आम्ही समस्येकडे दुर्लक्ष केल्यास आणि हळूहळू काहीतरी करू नये म्हणून उत्पादन CO2 नियंत्रित करू शकत नाही म्हणूनच आपण निसर्गास समजू शकतो की आपण निसर्गाशी सुसंगत राहू शकतो म्हणूनच निसर्गाला आपण निसटू द्यावे म्हणूनच निसर्ग आपल्याला बंद करतो , त्यामुळे सीओ 2 खाली येईल , ग्लोबल वार्मिंग  खाली येईल .
#
# आधीपासून पाहिले व्ही एकरुप व्ही v1 प्लस व्ही #N उजवीकडे
# आपण आधीपासून पाहिले आहे की व्ही एकरुप व्ही V1 प्लस व्ही 2 उजवीकडे आहे .
#
# याचाच अर्थ आमच्या उदाहरणामध्ये प्रक्रिया पी #N ची प्राधान्ये हळूहळू काळापेक्षा हळूहळू वाढू शकेल जोपर्यंत त्याकडे p1 p2 p3 प्रक्रियेच्या प्राधान्यापेक्षा मोठे किंवा समतुल्य
# याचाच अर्थ असा की , आमच्या उदाहरणामध्ये प्रक्रिया पी 4 ची प्राधान्ये हळूहळू काही काळापेक्षा हळूहळू वाढू शकेल जोपर्यंत त्याकडे P1 , P2 आणि P3 प्रक्रियेच्या प्राधान्यापेक्षा मोठे किंवा समतुल्य आहे .
#
# याचाच अर्थ आमच्या उदाहरणामध्ये प्रक्रिया पी #N ची प्राधान्ये हळूहळू काळापेक्षा हळूहळू वाढू शकेल जोपर्यंत त्याकडे p1 p2 p3 प्रक्रियेच्या प्राधान्यापेक्षा मोठे किंवा समतुल्य
# याचाच अर्थ असा की , आमच्या उदाहरणामध्ये प्रक्रिया पी 4 ची प्राधान्ये हळूहळू काही काळापेक्षा हळूहळू वाढू शकेल जोपर्यंत त्याकडे P1 , P2 आणि P3 प्रक्रियेच्या प्राधान्यापेक्षा मोठे किंवा समतुल्य आहे .
#
# याचाच अर्थ आमच्या उदाहरणामध्ये प्रक्रिया पी #N ची प्राधान्ये हळूहळू काळापेक्षा हळूहळू वाढू शकेल जोपर्यंत त्याकडे p1 p2 p3 प्रक्रियेच्या प्राधान्यापेक्षा मोठे किंवा समतुल्य
# याचाच अर्थ असा की , आमच्या उदाहरणामध्ये प्रक्रिया पी 4 ची प्राधान्ये हळूहळू काही काळापेक्षा हळूहळू वाढू शकेल जोपर्यंत त्याकडे P1 , P2 आणि P3 प्रक्रियेच्या प्राधान्यापेक्षा मोठे किंवा समतुल्य आहे .
#
# xv6 मध्ये मेमरी व्यवस्थापनाच्या पूर्ण दृश्यासाठी आम्ही विशिष्ट आकृती पाहिले
# xv6 मध्ये या मेमरी व्यवस्थापनाच्या पूर्ण दृश्यासाठी , आम्ही हे विशिष्ट आकृती पाहिले होते .
#
# प्रत्येक अनुप्रयोगास रेन बॉक्सिंग पर्यावरणातील चालवा खात्री करावी लागते application1 ला अॅप्लिकेशन #N बद्दल काहीही माहिती नसावी ऍप्लिकेशन #N मध्ये प्रणालीवर चालणार्या इतर अनुप्रयोगांबद्दल काहीही माहिती नसावी याप्रमाणे
# तर , प्रत्येक अनुप्रयोगास , रेन बॉक्सिंग पर्यावरणातील चालवा याची खात्री करावी लागते application1 ला अॅप्लिकेशन 2 बद्दल काहीही माहिती नसावी , ऍप्लिकेशन 2 मध्ये प्रणालीवर चालणार्या इतर अनुप्रयोगांबद्दल काहीही माहिती नसावी आणि याप्रमाणे .
#
# आपल्याला देखील माहित मूळ वायुमध्ये अर्धा rho av1 क्यूब ऊर्जा
# आपल्याला हे देखील माहित आहे की मूळ वायुमध्ये अर्धा rho AV1 क्यूब  ऊर्जा आहे .
#
# म्हणूया प्रक्रियेमुळे सेमाफॉर s1 s2 s3 च्या विनंतीस सुरवात
# तर , आता असे म्हणूया की या प्रक्रियेमुळे सेमाफॉर S1 , S2 आणि S3 च्या विनंतीस सुरवात होते .
#
# म्हणूया प्रक्रियेमुळे सेमाफॉर s1 s2 s3 च्या विनंतीस सुरवात
# तर , आता असे म्हणूया की या प्रक्रियेमुळे सेमाफॉर S1 , S2 आणि S3 च्या विनंतीस सुरवात होते .
#
# म्हणूया प्रक्रियेमुळे सेमाफॉर s1 s2 s3 च्या विनंतीस सुरवात
# तर , आता असे म्हणूया की या प्रक्रियेमुळे सेमाफॉर S1 , S2 आणि S3 च्या विनंतीस सुरवात होते .
#
# xv6 ऑपरेटिंग सिस्टीममध्ये आम्ही अभ्यासक्रमासाठी शोधत आहोत प्रक्रियेच्या अधिकतम आकाराचे पत्ता वर निश्चित
# Xv6 ऑपरेटिंग सिस्टीममध्ये जे आम्ही या अभ्यासक्रमासाठी शोधत आहोत , प्रक्रियेच्या अधिकतम आकाराचे पत्ता 0x80000000 वर निश्चित केले आहे .
#
# x86 प्रणालीमध्ये त्यात विभाजन म्हणूनच प्रत्येक इंटरप्ट डिस्क्रिप्टरमध्ये रेषाखंड निवडक ऑफसेटचा समावेश असेल
# X86 प्रणालीमध्ये , त्यात विभाजन आहे म्हणूनच , प्रत्येक इंटरप्ट डिस्क्रिप्टरमध्ये रेषाखंड निवडक तसेच ऑफसेटचा समावेश असेल .
#
# संख्या दृष्टीने आम्ही #N काउंटर काउंटर सामग्री #N आर #N मध्ये लोड नंतर #N वाढते r1 #N समाविष्टीत r1 मूल्य परत काउंटर परत
# त्यामुळे संख्या दृष्टीने , म्हणून आम्ही येथे 5 काउंटर आहे , त्यामुळे काउंटर सामग्री 5 आहे आणि ती आर 1 मध्ये लोड केले आहे , नंतर 5 वाढते आहे त्यामुळे आता R1 6 समाविष्टीत आहे आणि R1 मूल्य परत काउंटर परत आहे .
#
# संख्या दृष्टीने आम्ही #N काउंटर काउंटर सामग्री #N आर #N मध्ये लोड नंतर #N वाढते r1 #N समाविष्टीत r1 मूल्य परत काउंटर परत
# त्यामुळे संख्या दृष्टीने , म्हणून आम्ही येथे 5 काउंटर आहे , त्यामुळे काउंटर सामग्री 5 आहे आणि ती आर 1 मध्ये लोड केले आहे , नंतर 5 वाढते आहे त्यामुळे आता R1 6 समाविष्टीत आहे आणि R1 मूल्य परत काउंटर परत आहे .
#
# पी #N प्रथम कार्यान्वित करते नंतर तेथे p1 p3 कार्यान्वित करते नंतर p2 पुन्हा पुन्हा कार्यान्वित करते शेवटी विशिष्ट वेळेस स्फोट कार्यान्वित जातो
# तर , पी 2 प्रथम येथे कार्यान्वित करते आणि नंतर तेथे P1 आणि P3 कार्यान्वित करते , नंतर P2 पुन्हा पुन्हा कार्यान्वित करते आणि शेवटी या विशिष्ट वेळेस त्याचा स्फोट कार्यान्वित केला जातो .
#
# पी #N प्रथम कार्यान्वित करते नंतर तेथे p1 p3 कार्यान्वित करते नंतर p2 पुन्हा पुन्हा कार्यान्वित करते शेवटी विशिष्ट वेळेस स्फोट कार्यान्वित जातो
# तर , पी 2 प्रथम येथे कार्यान्वित करते आणि नंतर तेथे P1 आणि P3 कार्यान्वित करते , नंतर P2 पुन्हा पुन्हा कार्यान्वित करते आणि शेवटी या विशिष्ट वेळेस त्याचा स्फोट कार्यान्वित केला जातो .
#
# पी #N प्रथम कार्यान्वित करते नंतर तेथे p1 p3 कार्यान्वित करते नंतर p2 पुन्हा पुन्हा कार्यान्वित करते शेवटी विशिष्ट वेळेस स्फोट कार्यान्वित जातो
# तर , पी 2 प्रथम येथे कार्यान्वित करते आणि नंतर तेथे P1 आणि P3 कार्यान्वित करते , नंतर P2 पुन्हा पुन्हा कार्यान्वित करते आणि शेवटी या विशिष्ट वेळेस त्याचा स्फोट कार्यान्वित केला जातो .
#
# w3c द्वारे परिभाषित जाते नेमस्पेस रिकामे गणिताशी संबंधित नेमस्पेस
# जे W3C द्वारे परिभाषित केले जाते , तर हे नेमस्पेस रिकामे गणिताशी संबंधित नेमस्पेस आहे .
#
# पाहिलं xv6 कोड पेजिंगला कसे सक्षम करते पृष्ठे पेजेल्स पेज टेबल बनवते
# तर आता आपण पाहिलं आहे की xv6 कोड पेजिंगला कसे सक्षम करते पृष्ठे पेजेल्स तसेच पेज टेबल बनवते .
#
# आपणास अशा परिस्थितीत जावे लागेल जिथे आपल्याला माहित आहे की शहरे आणि देश वातावरणात CO2 च्या वाढीच्या परिणामास सामोरे जाऊ शकत नाहीत , जे खरोखरच ठीक आहे म्हणून ते गंभीरपणे संबोधित केले जात नाही .
#
# पुढील क्रिया करणे p4 किंवा #N असू शकते
# आता पुढील क्रिया करणे P4 किंवा P 5 असे असू शकते .
#
# ध्येय मालिकेसाठी मॉडेल करणे जेणेकरून co2 च्या पातळीची अंदाज घेण्यासाठी मॉडेलचा वापर करू शकेन
# तर , येथे ध्येय हे मालिकेसाठी मॉडेल करणे आहे , जेणेकरून मी CO2 च्या पातळीची अंदाज घेण्यासाठी त्या मॉडेलचा वापर करू शकेन .
#
# ध्वज p2 inside p1 inside गंभीर भागांच्या लॉकिंग अनलॉकिंग दरम्यान वापरले जातात
# आता या ध्वज p2 _ inside आणि p1 _ inside हे गंभीर भागांच्या लॉकिंग आणि अनलॉकिंग दरम्यान वापरले जातात .
#
# ध्वज p2 inside p1 inside गंभीर भागांच्या लॉकिंग अनलॉकिंग दरम्यान वापरले जातात
# आता या ध्वज p2 _ inside आणि p1 _ inside हे गंभीर भागांच्या लॉकिंग आणि अनलॉकिंग दरम्यान वापरले जातात .
#
# उदाहरणार्थ libc attack च्या पुनरागमनामध्ये हल्लेखोराने जाणून घेणे आवश्यक कार्यपद्धती f1 किंवा आमच्या उदाहरणामध्ये कार्यप्रणालीचे स्थान कार्यक्रम स्तराच्या ठिकाणी कोठे
# उदाहरणार्थ , libc attack च्या पुनरागमनामध्ये , हल्लेखोराने हे जाणून घेणे आवश्यक होते की कार्यपद्धती F1 किंवा आमच्या उदाहरणामध्ये कार्यप्रणालीचे स्थान कार्यक्रम स्तराच्या ठिकाणी कोठे आहे .
#
# x86 प्रणालीमध्ये सेगमेंटेशन युनिट कसा बनवला पाहू
# तर , आपण x86 प्रणालीमध्ये सेगमेंटेशन युनिट कसा बनवला आहे ते पाहू .
#
# तेथे तापमान दुधाची संरचना चव बदलत कारण पुन्हा q10 तापमान होईल
# मग तेथे कमी तापमान दुधाची संरचना आणि चव बदलत नाही कारण पुन्हा Q10 त्यामुळे तापमान कमी होईल .
#
# दुसरा दोष सरासरी प्रतीक्षा वेळा उच्च असतो विशेषतः जेव्हा बर्स्ट वेळा समान लांबी असतात xv6 शेड्यूलिंग पॉलिसी राउंड रॉबिन शेड्यूलिंग पॉलिसीचे प्रकार स्त्रोत कोड दर्शविला
# आणि दुसरा दोष म्हणजे सरासरी प्रतीक्षा वेळा उच्च असतो विशेषतः जेव्हा बर्स्ट वेळा समान लांबी असतात xv6 शेड्यूलिंग पॉलिसी राउंड रॉबिन शेड्यूलिंग पॉलिसीचे एक प्रकार आहे ; स्त्रोत कोड येथे दर्शविला आहे .
#
# #N मध्ये अलीकडेच x86 इव्होल्यूशनमध्ये पुढील मोठे पाऊल
# 2003 मध्ये अलीकडेच , x86 इव्होल्यूशनमध्ये पुढील मोठे पाऊल होते .
#
# पुढची गोष्ट आम्हाला विचार करण्याची गरज ऑपरेटिंग सिस्टम कसे किंवा xv6 os ठरवते कोणता पृष्ठ वाटप करावा पृष्ठ कसे मुक्त जावे
# आता , पुढची गोष्ट जी आम्हाला विचार करण्याची गरज आहे ते ऑपरेटिंग सिस्टम कसे आहे किंवा xv6 OS ठरवते की कोणता पृष्ठ वाटप करावा आणि पृष्ठ कसे मुक्त केले जावे ?
#
# ec2s अंतर्गत पत्ता स्थान उपलब्धता विभागात स्पष्टपणे विभाजित
# ...
#
# गोष्टी xv6 ऑपरेटिंग सिस्टमद्वारे केल्या जातात
# तर , या गोष्टी xv6 ऑपरेटिंग सिस्टमद्वारे केल्या जातात .
#
# चला ऑपरेटिंग सिस्टमचे उदाहरण घ्या कारमध्ये मायक्रो प्रोसेसर मध्ये चालते जेव्हा जेव्हा ब्रेक दाबायचे असेल तेव्हा प्रक्रिया p2 कार्यान्वित करेल कारच्या ब्रेकशी संबंधित कार्य करेल प्रक्रिया p1 p3 पी #N गंभीर कार्ये असू शकतात उदाहरणार्थ कारसाठी p1 p3 p4 कदाचित म्युझिक प्लेअर असेल प्रक्रिया म्युझिक प्लेअर असू शकेल दुसरा एसी किंवा हीटरला नियंत्रित करण्यासाठी असेल असेल
# तर चला एक ऑपरेटिंग सिस्टमचे एक उदाहरण घ्या जे एक कारमध्ये असलेल्या मायक्रो प्रोसेसर मध्ये चालते आणि जेव्हा जेव्हा ब्रेक दाबायचे असेल तेव्हा प्रक्रिया P2 कार्यान्वित करेल आणि ती कारच्या ब्रेकशी संबंधित काही कार्य करेल , प्रक्रिया P1 , P3 आणि पी 4 कमी गंभीर कार्ये असू शकतात उदाहरणार्थ कारसाठी P1 , P3 आणि P4 हे कदाचित म्युझिक प्लेअर असेल , त्यामुळे एक प्रक्रिया म्युझिक प्लेअर असू शकेल , तर दुसरा एसी किंवा हीटरला नियंत्रित करण्यासाठी असेल आणि असे असेल .
#
# चला ऑपरेटिंग सिस्टमचे उदाहरण घ्या कारमध्ये मायक्रो प्रोसेसर मध्ये चालते जेव्हा जेव्हा ब्रेक दाबायचे असेल तेव्हा प्रक्रिया p2 कार्यान्वित करेल कारच्या ब्रेकशी संबंधित कार्य करेल प्रक्रिया p1 p3 पी #N गंभीर कार्ये असू शकतात उदाहरणार्थ कारसाठी p1 p3 p4 कदाचित म्युझिक प्लेअर असेल प्रक्रिया म्युझिक प्लेअर असू शकेल दुसरा एसी किंवा हीटरला नियंत्रित करण्यासाठी असेल असेल
# तर चला एक ऑपरेटिंग सिस्टमचे एक उदाहरण घ्या जे एक कारमध्ये असलेल्या मायक्रो प्रोसेसर मध्ये चालते आणि जेव्हा जेव्हा ब्रेक दाबायचे असेल तेव्हा प्रक्रिया P2 कार्यान्वित करेल आणि ती कारच्या ब्रेकशी संबंधित काही कार्य करेल , प्रक्रिया P1 , P3 आणि पी 4 कमी गंभीर कार्ये असू शकतात उदाहरणार्थ कारसाठी P1 , P3 आणि P4 हे कदाचित म्युझिक प्लेअर असेल , त्यामुळे एक प्रक्रिया म्युझिक प्लेअर असू शकेल , तर दुसरा एसी किंवा हीटरला नियंत्रित करण्यासाठी असेल आणि असे असेल .
#
# चला ऑपरेटिंग सिस्टमचे उदाहरण घ्या कारमध्ये मायक्रो प्रोसेसर मध्ये चालते जेव्हा जेव्हा ब्रेक दाबायचे असेल तेव्हा प्रक्रिया p2 कार्यान्वित करेल कारच्या ब्रेकशी संबंधित कार्य करेल प्रक्रिया p1 p3 पी #N गंभीर कार्ये असू शकतात उदाहरणार्थ कारसाठी p1 p3 p4 कदाचित म्युझिक प्लेअर असेल प्रक्रिया म्युझिक प्लेअर असू शकेल दुसरा एसी किंवा हीटरला नियंत्रित करण्यासाठी असेल असेल
# तर चला एक ऑपरेटिंग सिस्टमचे एक उदाहरण घ्या जे एक कारमध्ये असलेल्या मायक्रो प्रोसेसर मध्ये चालते आणि जेव्हा जेव्हा ब्रेक दाबायचे असेल तेव्हा प्रक्रिया P2 कार्यान्वित करेल आणि ती कारच्या ब्रेकशी संबंधित काही कार्य करेल , प्रक्रिया P1 , P3 आणि पी 4 कमी गंभीर कार्ये असू शकतात उदाहरणार्थ कारसाठी P1 , P3 आणि P4 हे कदाचित म्युझिक प्लेअर असेल , त्यामुळे एक प्रक्रिया म्युझिक प्लेअर असू शकेल , तर दुसरा एसी किंवा हीटरला नियंत्रित करण्यासाठी असेल आणि असे असेल .
#
# चला ऑपरेटिंग सिस्टमचे उदाहरण घ्या कारमध्ये मायक्रो प्रोसेसर मध्ये चालते जेव्हा जेव्हा ब्रेक दाबायचे असेल तेव्हा प्रक्रिया p2 कार्यान्वित करेल कारच्या ब्रेकशी संबंधित कार्य करेल प्रक्रिया p1 p3 पी #N गंभीर कार्ये असू शकतात उदाहरणार्थ कारसाठी p1 p3 p4 कदाचित म्युझिक प्लेअर असेल प्रक्रिया म्युझिक प्लेअर असू शकेल दुसरा एसी किंवा हीटरला नियंत्रित करण्यासाठी असेल असेल
# तर चला एक ऑपरेटिंग सिस्टमचे एक उदाहरण घ्या जे एक कारमध्ये असलेल्या मायक्रो प्रोसेसर मध्ये चालते आणि जेव्हा जेव्हा ब्रेक दाबायचे असेल तेव्हा प्रक्रिया P2 कार्यान्वित करेल आणि ती कारच्या ब्रेकशी संबंधित काही कार्य करेल , प्रक्रिया P1 , P3 आणि पी 4 कमी गंभीर कार्ये असू शकतात उदाहरणार्थ कारसाठी P1 , P3 आणि P4 हे कदाचित म्युझिक प्लेअर असेल , त्यामुळे एक प्रक्रिया म्युझिक प्लेअर असू शकेल , तर दुसरा एसी किंवा हीटरला नियंत्रित करण्यासाठी असेल आणि असे असेल .
#
# चला ऑपरेटिंग सिस्टमचे उदाहरण घ्या कारमध्ये मायक्रो प्रोसेसर मध्ये चालते जेव्हा जेव्हा ब्रेक दाबायचे असेल तेव्हा प्रक्रिया p2 कार्यान्वित करेल कारच्या ब्रेकशी संबंधित कार्य करेल प्रक्रिया p1 p3 पी #N गंभीर कार्ये असू शकतात उदाहरणार्थ कारसाठी p1 p3 p4 कदाचित म्युझिक प्लेअर असेल प्रक्रिया म्युझिक प्लेअर असू शकेल दुसरा एसी किंवा हीटरला नियंत्रित करण्यासाठी असेल असेल
# तर चला एक ऑपरेटिंग सिस्टमचे एक उदाहरण घ्या जे एक कारमध्ये असलेल्या मायक्रो प्रोसेसर मध्ये चालते आणि जेव्हा जेव्हा ब्रेक दाबायचे असेल तेव्हा प्रक्रिया P2 कार्यान्वित करेल आणि ती कारच्या ब्रेकशी संबंधित काही कार्य करेल , प्रक्रिया P1 , P3 आणि पी 4 कमी गंभीर कार्ये असू शकतात उदाहरणार्थ कारसाठी P1 , P3 आणि P4 हे कदाचित म्युझिक प्लेअर असेल , त्यामुळे एक प्रक्रिया म्युझिक प्लेअर असू शकेल , तर दुसरा एसी किंवा हीटरला नियंत्रित करण्यासाठी असेल आणि असे असेल .
#
# चला ऑपरेटिंग सिस्टमचे उदाहरण घ्या कारमध्ये मायक्रो प्रोसेसर मध्ये चालते जेव्हा जेव्हा ब्रेक दाबायचे असेल तेव्हा प्रक्रिया p2 कार्यान्वित करेल कारच्या ब्रेकशी संबंधित कार्य करेल प्रक्रिया p1 p3 पी #N गंभीर कार्ये असू शकतात उदाहरणार्थ कारसाठी p1 p3 p4 कदाचित म्युझिक प्लेअर असेल प्रक्रिया म्युझिक प्लेअर असू शकेल दुसरा एसी किंवा हीटरला नियंत्रित करण्यासाठी असेल असेल
# तर चला एक ऑपरेटिंग सिस्टमचे एक उदाहरण घ्या जे एक कारमध्ये असलेल्या मायक्रो प्रोसेसर मध्ये चालते आणि जेव्हा जेव्हा ब्रेक दाबायचे असेल तेव्हा प्रक्रिया P2 कार्यान्वित करेल आणि ती कारच्या ब्रेकशी संबंधित काही कार्य करेल , प्रक्रिया P1 , P3 आणि पी 4 कमी गंभीर कार्ये असू शकतात उदाहरणार्थ कारसाठी P1 , P3 आणि P4 हे कदाचित म्युझिक प्लेअर असेल , त्यामुळे एक प्रक्रिया म्युझिक प्लेअर असू शकेल , तर दुसरा एसी किंवा हीटरला नियंत्रित करण्यासाठी असेल आणि असे असेल .
#
# xv6 मधील फोर्कची अंमलबजावणी दर्शविल्याप्रमाणे
# येथे xv6 मधील फोर्कची अंमलबजावणी ही येथे दर्शविल्याप्रमाणे आहे .
#
# म्हणूनच xv6 ज्या पद्धतीने बनवले गेले प्रत्यक्षात linux सारख्या ऑपरेटिंग सिस्टम्स अशा विविध unix
# म्हणूनच xv6 हे ज्या पद्धतीने बनवले गेले आहे , ते म्हणजे प्रत्यक्षात Linux सारख्या ऑपरेटिंग सिस्टम्स अशा विविध UNIX म्हणजे काय .
#
# पुढे सेगमेंटेशन पासून पेजिंग युनिटकडे जा xv6 ऑपरेटिंग सिस्टीममध्ये वर्च्युअल मेमरी कशी व्यवस्थापित जाते
# पुढे आपण सेगमेंटेशन पासून पेजिंग युनिटकडे जा , म्हणजे xv6 ऑपरेटिंग सिस्टीममध्ये वर्च्युअल मेमरी कशी व्यवस्थापित केली जाते .
#
# अर्थ सहजतेने दिशा ज्यामुळे सी ओ #N सह प्रतिक्रिया देईल co2 फॉर्म तयार करेल
# याचा अर्थ असा आहे की हे सहजतेने एक दिशा आहे ज्यामुळे ते सी ओ2  सह प्रतिक्रिया देईल आणि CO2 फॉर्म तयार करेल .
#
# नकाशातील कार्य प्रत्येक शब्दासाठी शब्द दस्तऐवज रेकॉर्ड आयडी जोडी जसे wdk w1
# म्हणून , नकाशातील कार्य प्रत्येक शब्दासाठी शब्द दस्तऐवज , रेकॉर्ड आयडी  जोडी , जसे की आपण wdk w1 .
#
# आम्ही पाहू कसे इंटेल x86 सिस्टीम दोन्ही विभागातील पेजिंगचा वापर करते जेणेकरून दोघांचे फायदे प्राप्त म्हणूनच x86 प्रणालीमध्ये सीपीयू रेग्युलर ऑफसेटचे लॉजिकल एड्रेस तयार करतो सेगमेंटेशन युनिटला पाठविला जातो नंतर रेखीय पत्ता तयार करतो
# आम्ही आता पाहू की कसे इंटेल x86 सिस्टीम दोन्ही विभागातील तसेच पेजिंगचा वापर करते , जेणेकरून दोघांचे फायदे प्राप्त आहेत म्हणूनच , x86 प्रणालीमध्ये , सीपीयू रेग्युलर आणि ऑफसेटचे लॉजिकल एड्रेस तयार करतो म्हणून हा एक सेगमेंटेशन युनिटला पाठविला जातो जो नंतर एक रेखीय पत्ता तयार करतो .
#
# आम्ही पाहू कसे इंटेल x86 सिस्टीम दोन्ही विभागातील पेजिंगचा वापर करते जेणेकरून दोघांचे फायदे प्राप्त म्हणूनच x86 प्रणालीमध्ये सीपीयू रेग्युलर ऑफसेटचे लॉजिकल एड्रेस तयार करतो सेगमेंटेशन युनिटला पाठविला जातो नंतर रेखीय पत्ता तयार करतो
# आम्ही आता पाहू की कसे इंटेल x86 सिस्टीम दोन्ही विभागातील तसेच पेजिंगचा वापर करते , जेणेकरून दोघांचे फायदे प्राप्त आहेत म्हणूनच , x86 प्रणालीमध्ये , सीपीयू रेग्युलर आणि ऑफसेटचे लॉजिकल एड्रेस तयार करतो म्हणून हा एक सेगमेंटेशन युनिटला पाठविला जातो जो नंतर एक रेखीय पत्ता तयार करतो .
तयार केले गेले आहे , मग आपण वातावरणात कार्बन डाय ऑक्साईड सोडत आहात म्हणून , सीओ 2 एक घटक आहे ज्यास आपण लक्ष ठेवण्याची गरज आहे आणि आज जागतिक तापमानवाढीसाठी सीओ 2 हा एक प्रमुख योगदानकर्ता आहे म्हणून आम्हाला आपणास माहित आहे की आपण वातावरणात किती सीओ 2 टाकत आहोत आणि किती फरक पडणार आहे हे फरक आहे तर , मी हे देखील दर्शवितो की या गणनामध्ये आम्ही जल वाष्प अस्तित्वात नाही तर मी या मोजणीत काही गोष्टींचा अंदाज घेईन कारण आम्ही हे गणित केवळ इतकेच करतो जेणेकरुन आपण येथे किती संख्येने हाताळत आहोत यावर काही नियंत्रण आपल्याला कळू शकेल .
#
# उदाहरणार्थ application1 अशा स्कॅनफ सारख्या इव्हेंटच्या प्रतीक्षेत मूलत कीबोर्डवर काहीतरी इनपुट करण्यासाठी वापरकर्त्यासाठी प्रतीक्षेत
# उदाहरणार्थ , application1 अशा स्कॅनफ सारख्या इव्हेंटच्या प्रतीक्षेत आहे मूलत : ते कीबोर्डवर काहीतरी इनपुट करण्यासाठी वापरकर्त्यासाठी प्रतीक्षेत आहे .
#
# बाबतीत amd x86 #N
# या बाबतीत तो AMD x86 - 64 आहे .
#
# अभ्यासक्रमासाठी अभ्यास करणार्या ऑपरेटिंग सिस्टीम xv6 os एमआयटीने शिकविण्याच्या हेतूने तयार
# आपण या अभ्यासक्रमासाठी अभ्यास करणार्या ऑपरेटिंग सिस्टीम म्हणजे xv6 OS आहे जे एमआयटीने शिकविण्याच्या हेतूने तयार केले आहे .
#
# त्यांना cd1 cd #N म्हणूया
# आपण त्यांना CD1 आणि CD 2 म्हणूया .
#
# ptable मूलत procs अॅरे समाविष्टीत ऍरेचे आकार nproc प्रक्रियांची एकूण संख्या प्राप्त xv6 os वर वेळी चालवता येते
# Ptable मूलत : procs एक अॅरे समाविष्टीत आहे , ऍरेचे आकार NPROC आहे जे प्रक्रियांची एकूण संख्या प्राप्त होते , ते xv6 OS वर एका वेळी चालवता येते .
#
# चला पाहू xv6 ऑपरेटिंग सिस्टीम विविध कारणांसाठी मेमरी कसे वाटप करते
# चला पाहू या xv6 ऑपरेटिंग सिस्टीम विविध कारणांसाठी मेमरी कसे वाटप करते .
#
# rho alv1 minus v2 स्थिर वारामिलपासून खूप दूर
# rho ALV1 minus V2  हे स्थिर आहे व वारामिलपासून खूप दूर आहे .
#
# rho alv1 minus v2 स्थिर वारामिलपासून खूप दूर
# rho ALV1 minus V2  हे स्थिर आहे व वारामिलपासून खूप दूर आहे .
#
# कोर्समधे इंटेल x86 प्रोसेसर लक्षात ठेवून अभ्यास करू
# तर , या कोर्समधे आपण इंटेल x86 प्रोसेसर  लक्षात ठेवून अभ्यास करू .
#
# सूची xv6 स्रोत कोडच्या proc dot फाइलमधून मिळविली जाते
# म्हणून , ही सूची xv6 स्रोत कोडच्या proc dot c फाइलमधून मिळविली जाते .
#
#
# पुन्हा म्हणालो क्षणी म्हणू शकता कार्बोक्सिलिक ऍसिडशिवाय नंबर सी #N बरोबर असेल पुन्हा गोंधळाने आपल्याला खूप विशिष्ट असणे आवश्यक म्हणूनच स्पष्टपणे c4 बरोबर ब्यूटरीक ऍसिडचे सूत्र दिले
# पुन्हा मी असे म्हणालो की काही क्षणी आपण असे म्हणू शकता की कार्बोक्सिलिक ऍसिडशिवाय हे नंबर सी 3 बरोबर असेल म्हणून पुन्हा या गोंधळाने आपल्याला खूप विशिष्ट असणे आवश्यक नाही म्हणूनच स्पष्टपणे मी C4 बरोबर ब्यूटरीक ऍसिडचे सूत्र दिले आहे .
#
# xv6 वेगवेगळ्या नावांनी स्थितीला कॉल करते जसे नवीला भ्रुण म्हणतात ज्याचा अर्थ नवीन प्रक्रिया सध्या तयार जेव्हा ready चालवण्यायोग्य ओळखली जाते ज्याचा अर्थ चालण्यासाठी तयार स्लीपिंगला ओळखले जाते
# Xv6 वेगवेगळ्या नावांनी या स्थितीला कॉल करते , जसे की नवीला भ्रुण म्हणतात ज्याचा अर्थ असा की एक नवीन प्रक्रिया सध्या तयार केली जात आहे , जेव्हा की READY चालवण्यायोग्य म्हणून ओळखली जाते ज्याचा अर्थ आहे तो चालण्यासाठी तयार आहे , तर स्लीपिंगला म्हणून ओळखले जाते .
#
# आम्ही x86 प्रणालीमध्ये आधी पाहिल्याप्रमाणे व्हर्च्युअल अॅड्रेस सिंक्रोनाइझ्ड प्रत्यक्षात पेज डायरेक्टरीच्या स्तरांद्वारे व्यवस्थापित जाते
# आम्ही x86 प्रणालीमध्ये आधी पाहिल्याप्रमाणे , व्हर्च्युअल अॅड्रेस सिंक्रोनाइझ्ड प्रत्यक्षात पेज डायरेक्टरीच्या दोन स्तरांद्वारे व्यवस्थापित केले जाते .
# विशिष्ट वस्तू #N mb विशिष्ट बिंदू किंवा विशिष्ट पत्ता प्रथम भौतिक पत्ता पत्ता बसमध्ये cpu द्वारे ठेवले ffff0 विशिष्ट #N mb च्या खाली #N बाइट
# म्हणून , 0x12345 ही विशिष्ट वस्तू 1 MB आहे हा विशिष्ट बिंदू किंवा या विशिष्ट पत्ता आणि प्रथम भौतिक पत्ता जो पत्ता बसमध्ये CPU द्वारे ठेवले आहे तो ffff0 आहे जे या विशिष्ट 1 MB च्या खाली 16 बाइट आहे .
#
# याव्यतिरिक्त p1 p2 p3 p4 #N कळा नंतर पुन्हा तयार रांगेत पुन्हा पोहोचतात
# याव्यतिरिक्त , P1 , P2 , P3 आणि P4 15 कळा नंतर पुन्हा तयार रांगेत पुन्हा पोहोचतात .
#
# याव्यतिरिक्त p1 p2 p3 p4 #N कळा नंतर पुन्हा तयार रांगेत पुन्हा पोहोचतात
# याव्यतिरिक्त , P1 , P2 , P3 आणि P4 15 कळा नंतर पुन्हा तयार रांगेत पुन्हा पोहोचतात .
#
# याव्यतिरिक्त p1 p2 p3 p4 #N कळा नंतर पुन्हा तयार रांगेत पुन्हा पोहोचतात
# याव्यतिरिक्त , P1 , P2 , P3 आणि P4 15 कळा नंतर पुन्हा तयार रांगेत पुन्हा पोहोचतात .
#
# याव्यतिरिक्त p1 p2 p3 p4 #N कळा नंतर पुन्हा तयार रांगेत पुन्हा पोहोचतात
# याव्यतिरिक्त , P1 , P2 , P3 आणि P4 15 कळा नंतर पुन्हा तयार रांगेत पुन्हा पोहोचतात .
#
# पृष्ठ निर्देशिका विशेष सारणी कि रॅममध्ये cr3 रजिस्टर द्वारे त्याला निर्देशित
# पृष्ठ निर्देशिका हा एक विशेष सारणी आहे जो कि रॅममध्ये आहे आणि CR3 रजिस्टर द्वारे त्याला निर्देशित केले आहे .
#
# आपल्याला दिसेल s2 एस s1 पेक्षा मोठे s3 s2 पेक्षा मोठे
# तर आपल्याला दिसेल की S2 एस S1 पेक्षा मोठे आहे आणि S3 S2 पेक्षा मोठे आहे .
#
# आपल्याला दिसेल s2 एस s1 पेक्षा मोठे s3 s2 पेक्षा मोठे
# तर आपल्याला दिसेल की S2 एस S1 पेक्षा मोठे आहे आणि S3 S2 पेक्षा मोठे आहे .
#
# आपल्याला दिसेल s2 एस s1 पेक्षा मोठे s3 s2 पेक्षा मोठे
# तर आपल्याला दिसेल की S2 एस S1 पेक्षा मोठे आहे आणि S3 S2 पेक्षा मोठे आहे .
#
# आपल्याला दिसेल s2 एस s1 पेक्षा मोठे s3 s2 पेक्षा मोठे
# तर आपल्याला दिसेल की S2 एस S1 पेक्षा मोठे आहे आणि S3 S2 पेक्षा मोठे आहे .
#
# सामान्य ऑपरेटिंग सिस्टम जसे linux xv6 ms dos अखंड रचना वापरतात
# म्हणून , सामान्य ऑपरेटिंग सिस्टम जसे की Linux आणि xv6 आणि MS - DOS एक अखंड रचना वापरतात .

# %%
for word in numbers:
    print(word)
# Out:
# 5
# ०
# ००
# १
# ४

# %% [markdown]
# # Get Word-Embeddings

# %%
def get_embedding_dict(embedding_path, vocab):
    embedding_dict = dict()
    vocab_words = set(vocab.keys())
    embedding_file = open(embedding_path, 'r')
    for row in embedding_file:
        row = row.split()
        word = row[0].strip()
        wv = np.asarray(row[1:], dtype='float32')
        if len(wv) == 300:
            embedding_dict[word] = wv
    return embedding_dict

# %%
embedding_path_ft = "/home/eastwind/word-embeddings/fasttext/cc.mr.300.vec"
embedding_dict_ft = get_embedding_dict(embedding_path_ft, bow_vectorizer.vocabulary_)
print(len(embedding_dict_ft))
# Out:
# 845805

# %%
embedding_path_indic = "/home/eastwind/word-embeddings/fasttext/indicnlp.ft.mr.300.vec"
embedding_dict_indic = get_embedding_dict(embedding_path_indic, bow_vectorizer.vocabulary_)
print(len(embedding_dict_indic))
# Out:
# 258413

# %%
embedding_path_ds = "/home/eastwind/word-embeddings/fasttext/TechDofication.ft.skipgram.mr.epoch50.d300.vec"
embedding_dict_ds = get_embedding_dict(embedding_path_ds, bow_vectorizer.vocabulary_)
print(len(embedding_dict_ds))
# Out:
# 51962

# %%
ft_words = [x for x in embedding_dict_ft.keys()]
indic_words = [x for x in embedding_dict_indic.keys()]
ds_words = [x for x in embedding_dict_ds.keys()]
word_list = bow_vectorizer.get_feature_names()

# %%
print("Fasttext Vocabulary: ", len(ft_words))
print("\nIndic-Fasttext Vocabulary: ", len(indic_words))
print("\nDS-Fasttext Vocabulary: ", len(ds_words))
# Out:
# Fasttext Vocabulary:  845805
#
# Indic-Fasttext Vocabulary:  258413
#
# DS-Fasttext Vocabulary:  51962

# %% [markdown]
# # Get Union and Interseciton

# %%
union1 = set(ft_words) | set(indic_words)
print("Fasttext and Indic-fasttext union Vocabulary: ", len(union1))
union2 = set(ft_words) | set(ds_words)
print("\nFasttext and DS-fasttext union Vocabulary: ", len(union2))
union3 = set(indic_words) | set(ds_words)
print("\nIndic-fasttext and DS-fasttext union Vocabulary: ", len(union3))
union= set(ft_words) | set(indic_words) | set(ds_words)
print("\nFasttext, Indic-fasttext, and DS-fasttext union Vocabulary: ", len(union))
# Out:
# Fasttext and Indic-fasttext union Vocabulary:  903109
#
# Fasttext and DS-fasttext union Vocabulary:  864982
#
# Indic-fasttext and DS-fasttext union Vocabulary:  281086
#
# Fasttext, Indic-fasttext, and DS-fasttext union Vocabulary:  921416

# %%
with open("vocabulary/ft-ds-union.txt", "w") as outfile:
    outfile.write("\n".join(union2))

# %%
with open("vocabulary/indic-ds-union.txt", "w") as outfile:
    outfile.write("\n".join(union3))

# %%
intersect1 = set(ft_words) & set(indic_words)
print("Fasttext and Indic-fasttext interesction Vocabulary: ", len(intersect1))
intersect2 = set(ft_words) & set(ds_words)
print("\nFasttext and DS-fasttext interesction Vocabulary: ", len(intersect2))
intersect3 = set(indic_words) & set(ds_words)
print("\nIndic-fasttext and DS-fasttext interesction Vocabulary: ", len(intersect3))
intersect= set(ft_words) & set(indic_words) & set(ds_words)
print("\nFasttext, Indic-fasttext, and DS-fasttext interesction Vocabulary: ", len(intersect))
# Out:
# Fasttext and Indic-fasttext interesction Vocabulary:  201109
#
# Fasttext and DS-fasttext interesction Vocabulary:  32785
#
# Indic-fasttext and DS-fasttext interesction Vocabulary:  29289
#
# Fasttext, Indic-fasttext, and DS-fasttext interesction Vocabulary:  28419

# %%
with open("vocabulary/ft-ds-intersection.txt", "w") as outfile:
    outfile.write("\n".join(intersect2))

# %%
with open("vocabulary/indic-ds-intersection.txt", "w") as outfile:
    outfile.write("\n".join(intersect3))

# %% [markdown]
# # Visualize Embeddings

# %%
def visualize_embeddings(words, embeddings):
        vectors = []
    
        # convert both lists into numpy vectors for reduction
        embeddings = np.asarray(embeddings)
        words = np.asarray(words)

        vectors = np.asarray(vectors)
        tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
        vectors = tsne_model.fit_transform(embeddings)
        print(vectors.shape)

        x = []
        y = []
        for value in vectors:
            x.append(value[0])
            y.append(value[1])

        plt.figure() 
        
        for i in range(len(x)):
            plt.scatter(x[i],y[i])
            plt.annotate(words[i],
                         xy=(x[i], y[i]),
                         xytext=(5, 2),
                         textcoords='offset points',
                         ha='right',
                         va='bottom')
       
        plt.show()

# %%
words = []
embeddings = []

word = "देशांचा"
embeddings.append(embedding_dict_ft[word])
words.append("fasttext")
embeddings.append(embedding_dict_indic[word])
words.append("indic-fasttext")
embeddings.append(embedding_dict_ds[word])
words.append("DS-fasttext")

# %%
visualize_embeddings(words, embeddings)
# Out:
# (3, 2)
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
for word in intersect:
    embeddings.append(embedding_dict_ft[word])
    words.append("fasttext")
    embeddings.append(embedding_dict_indic[word])
    words.append("indic-fasttext")
    embeddings.append(embedding_dict_ds[word])
    words.append("DS-fasttext")

# %%
visualize_embeddings(words[:15], embeddings[:15])
# Out:
# (15, 2)
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
def analyze_vocab(vocab_words):
    numbers = []
    english_words = []
    marathi_words = []
    for word in vocab_words:
        #if any(map(str.isdigit, word)):
        if re.match('\d+', word):
            numbers.append(word)
        elif re.match('[a-zA-Z]+', word):
            english_words.append(word)
        else:
            marathi_words.append(word)
    return numbers, english_words, marathi_words

# %%
vocab_words = bow_vectorizer.get_feature_names()

# %%
print("Total Vocabulary: ", len(vocab_words))
numbers, english_words, marathi_words = analyze_vocab(vocab_words)
print(len(numbers))
print(len(english_words))
print(len(marathi_words))
# Out:
# Total Vocabulary:  51774
# 17
# 881
# 50876

# %%
embeddings = []
words = []
for word in numbers:
    embeddings.append(embedding_dict_ds[word])
    words.append("DS-fasttext")

# %%
visualize_embeddings(words, embeddings)
# Out:
# (17, 2)
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
char = []
domain = []
reason = []
spcl_words = ['ºC', 'δδ', 'δδt', 'δवाढतो,' 'ε', 'εi', 'ηi', 'ρ', 'σ', 'σD', 'σμ', 'ω']

for text, label in list(zip(x_train, y_train)):
    for x in text.split():
        if x in english_words:
            domain.append(label)
            char.append(x)
            reason.append('english')
        elif x in numbers:
            domain.append(label)
            char.append(x)
            reason.append('number')
        elif x in spcl_words:
            domain.append(label)
            char.append(x)
            reason.append('spcl_char')
        

df = pd.DataFrame(list(zip(reason, char, domain)), columns=['reason', 'char', 'domain'])
df
# Out:
#        reason           char  domain
# 0     english              z  bioche
# 1     english              z  bioche
# 2     english            ram     cse
# 3     english              p     cse
# 4     english  unambiguously     cse
# ...       ...            ...     ...
# 3704  english            xml     cse
# 3705  english          linux     cse
# 3706  english             ms     cse
# 3707  english            dos     cse
# 3708  english            pci     cse
#
# [3709 rows x 3 columns]

# %%
df[df.reason == 'english'].domain.value_counts()
# Out:
# cse         2262
# com_tech     861
# phy          367
# bioche       152
# Name: domain, dtype: int64

# %%
df[df.reason == 'number'].domain.value_counts()
# Out:
# phy         30
# com_tech    15
# bioche       2
# Name: domain, dtype: int64

# %%
df[df.reason == 'spcl_char'].domain.value_counts()
# Out:
# com_tech    9
# cse         6
# bioche      3
# phy         2
# Name: domain, dtype: int64

# %%
embeddings = []
words = []
temp = df[df.reason == 'spcl_char']
spcl_words = temp[temp.domain == 'cse'].char.values.tolist()

for word in spcl_words:
    embeddings.append(embedding_dict_ds[word])
    words.append(word)
print(len(words))
# Out:
# 6

# %%
visualize_embeddings(words, embeddings)
# Out:
# (6, 2)
# <img src="data:image/png;base64,..." width="639.9999861283738">
